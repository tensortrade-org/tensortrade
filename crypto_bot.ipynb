# %% [markdown]
# Cryptocurrency trading bot.

# %% [markdown]
# Library imports.

# %%
import pandas as pd, random, time

from binance.exceptions import BinanceAPIException
from tensortrade.binance import Binance

# %% [markdown]
# Program parameters.

# %%
intervals = ['1m']
symbol = 'SCRTUSDT'
DELAY = 5
count = 1

# %% [markdown]
# Program initialization.

# %%
crypto = Binance(use_futures=False)
spot_client = crypto.spot_client
futures_client = crypto.futures_client

crypto.make_pair(symbol, intervals=intervals, download=True)
pair = crypto.pair

# %%
spot_client.get_ticker()
# Out:
# [{'symbol': 'ETHBTC',
#   'priceChange': '0.00076500',
#   'priceChangePercent': '1.155',
#   'weightedAvgPrice': '0.06592771',
#   'prevClosePrice': '0.06621800',
#   'lastPrice': '0.06698300',
#   'lastQty': '0.86930000',
#   'bidPrice': '0.06698200',
#   'bidQty': '0.05000000',
#   'askPrice': '0.06698300',
#   'askQty': '26.07910000',
#   'openPrice': '0.06621800',
#   'highPrice': '0.06715500',
#   'lowPrice': '0.06513000',
#   'volume': '86662.19930000',
#   'quoteVolume': '5713.44040480',
#   'openTime': 1646354915248,
#   'closeTime': 1646441315248,
#   'firstId': 328274986,
#   'lastId': 328464043,
#   'count': 189058},
#  {'symbol': 'LTCBTC',
#   'priceChange': '-0.00002800',
#   'priceChangePercent': '-1.074',
#   'weightedAvgPrice': '0.00258570',
#   'prevClosePrice': '0.00260800',
#   'lastPrice': '0.00257800',
#   'lastQty': '0.13000000',
#   'bidPrice': '0.00257800',
#   'bidQty': '11.87000000',
#   'askPrice': '0.00257900',
#   'askQty': '27.74500000',
#   'openPrice': '0.00260600',
#   'highPrice': '0.00262400',
#   'lowPrice': '0.00255900',
#   'volume': '91843.57600000',
#   'quoteVolume': '237.47951897',
#   'openTime': 1646354914211,
#   'closeTime': 1646441314211,
#   'firstId': 77504701,
#   'lastId': 77534871,
#   'count': 30171},
#  {'symbol': 'BNBBTC',
#   'priceChange': '0.00002000',
#   'priceChangePercent': '0.211',
#   'weightedAvgPrice': '0.00954028',
#   'prevClosePrice': '0.00949200',
#   'lastPrice': '0.00951000',
#   'lastQty': '0.22900000',
#   'bidPrice': '0.00951000',
#   'bidQty': '31.20500000',
#   'askPrice': '0.00951100',
#   'askQty': '25.15400000',
#   'openPrice': '0.00949000',
#   'highPrice': '0.00964900',
#   'lowPrice': '0.00941700',
#   'volume': '100394.56200000',
#   'quoteVolume': '957.79226593',
#   'openTime': 1646354915288,
#   'closeTime': 1646441315288,
#   'firstId': 180599101,
#   'lastId': 180665247,
#   'count': 66147},
#  {'symbol': 'NEOBTC',
#   'priceChange': '-0.00001100',
#   'priceChangePercent': '-2.007',
#   'weightedAvgPrice': '0.00054690',
#   'prevClosePrice': '0.00054800',
#   'lastPrice': '0.00053700',
#   'lastQty': '113.97000000',
#   'bidPrice': '0.00053700',
#   'bidQty': '318.79000000',
#   'askPrice': '0.00053800',
#   'askQty': '369.00000000',
#   'openPrice': '0.00054800',
#   'highPrice': '0.00055600',
#   'lowPrice': '0.00053600',
#   'volume': '38830.49000000',
#   'quoteVolume': '21.23641625',
#   'openTime': 1646354912262,
#   'closeTime': 1646441312262,
#   'firstId': 43012616,
#   'lastId': 43017651,
#   'count': 5036},
#  {'symbol': 'QTUMETH',
#   'priceChange': '-0.00003500',
#   'priceChangePercent': '-1.551',
#   'weightedAvgPrice': '0.00227749',
#   'prevClosePrice': '0.00226500',
#   'lastPrice': '0.00222100',
#   'lastQty': '4.10000000',
#   'bidPrice': '0.00222000',
#   'bidQty': '200.40000000',
#   'askPrice': '0.00222600',
#   'askQty': '86.40000000',
#   'openPrice': '0.00225600',
#   'highPrice': '0.00232000',
#   'lowPrice': '0.00222000',
#   'volume': '12699.00000000',
#   'quoteVolume': '28.92185250',
#   'openTime': 1646354912645,
#   'closeTime': 1646441312645,
#   'firstId': 5204138,
#   'lastId': 5204932,
#   'count': 795},
#  {'symbol': 'EOSETH',
#   'priceChange': '-0.00000200',
#   'priceChangePercent': '-0.262',
#   'weightedAvgPrice': '0.00076772',
#   'prevClosePrice': '0.00076800',
#   'lastPrice': '0.00076200',
#   'lastQty': '1079.90000000',
#   'bidPrice': '0.00076100',
#   'bidQty': '4131.20000000',
#   'askPrice': '0.00076300',
#   'askQty': '1147.40000000',
#   'openPrice': '0.00076400',
#   'highPrice': '0.00077600',
#   'lowPrice': '0.00075500',
#   'volume': '215500.90000000',
#   'quoteVolume': '165.44464730',
#   'openTime': 1646354915341,
#   'closeTime': 1646441315341,
#   'firstId': 22967710,
#   'lastId': 22968794,
#   'count': 1085},
#  {'symbol': 'SNTETH',
#   'priceChange': '0.00000046',
#   'priceChangePercent': '2.320',
#   'weightedAvgPrice': '0.00002025',
#   'prevClosePrice': '0.00001989',
#   'lastPrice': '0.00002029',
#   'lastQty': '502.00000000',
#   'bidPrice': '0.00002030',
#   'bidQty': '4230.00000000',
#   'askPrice': '0.00002038',
#   'askQty': '36903.00000000',
#   'openPrice': '0.00001983',
#   'highPrice': '0.00002092',
#   'lowPrice': '0.00001954',
#   'volume': '2498767.00000000',
#   'quoteVolume': '50.59710159',
#   'openTime': 1646354892683,
#   'closeTime': 1646441292683,
#   'firstId': 3422802,
#   'lastId': 3423621,
#   'count': 820},
#  {'symbol': 'BNTETH',
#   'priceChange': '-0.00000800',
#   'priceChangePercent': '-0.945',
#   'weightedAvgPrice': '0.00085006',
#   'prevClosePrice': '0.00084700',
#   'lastPrice': '0.00083900',
#   'lastQty': '68.60000000',
#   'bidPrice': '0.00084000',
#   'bidQty': '15.30000000',
#   'askPrice': '0.00084200',
#   'askQty': '378.70000000',
#   'openPrice': '0.00084700',
#   'highPrice': '0.00085600',
#   'lowPrice': '0.00083900',
#   'volume': '35212.10000000',
#   'quoteVolume': '29.93253840',
#   'openTime': 1646354914277,
#   'closeTime': 1646441314277,
#   'firstId': 2013338,
#   'lastId': 2013987,
#   'count': 650},
#  {'symbol': 'BCCBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.07908100',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'GASBTC',
#   'priceChange': '0.00000380',
#   'priceChangePercent': '3.375',
#   'weightedAvgPrice': '0.00011572',
#   'prevClosePrice': '0.00011280',
#   'lastPrice': '0.00011640',
#   'lastQty': '1.60000000',
#   'bidPrice': '0.00011630',
#   'bidQty': '16.20000000',
#   'askPrice': '0.00011650',
#   'askQty': '52.00000000',
#   'openPrice': '0.00011260',
#   'highPrice': '0.00012050',
#   'lowPrice': '0.00011160',
#   'volume': '88655.60000000',
#   'quoteVolume': '10.25933761',
#   'openTime': 1646354912919,
#   'closeTime': 1646441312919,
#   'firstId': 18047170,
#   'lastId': 18051477,
#   'count': 4308},
#  {'symbol': 'BNBETH',
#   'priceChange': '-0.00130000',
#   'priceChangePercent': '-0.907',
#   'weightedAvgPrice': '0.14450823',
#   'prevClosePrice': '0.14330000',
#   'lastPrice': '0.14200000',
#   'lastQty': '0.08000000',
#   'bidPrice': '0.14190000',
#   'bidQty': '56.38600000',
#   'askPrice': '0.14200000',
#   'askQty': '44.78700000',
#   'openPrice': '0.14330000',
#   'highPrice': '0.14620000',
#   'lowPrice': '0.14140000',
#   'volume': '25309.33800000',
#   'quoteVolume': '3657.40759970',
#   'openTime': 1646354912038,
#   'closeTime': 1646441312038,
#   'firstId': 45138719,
#   'lastId': 45156995,
#   'count': 18277},
#  {'symbol': 'BTCUSDT',
#   'priceChange': '-2815.25000000',
#   'priceChangePercent': '-6.755',
#   'weightedAvgPrice': '40661.95833314',
#   'prevClosePrice': '41675.82000000',
#   'lastPrice': '38860.58000000',
#   'lastQty': '0.00051000',
#   'bidPrice': '38860.57000000',
#   'bidQty': '0.37240000',
#   'askPrice': '38860.58000000',
#   'askQty': '2.69456000',
#   'openPrice': '41675.83000000',
#   'highPrice': '41904.88000000',
#   'lowPrice': '38550.00000000',
#   'volume': '62090.78425000',
#   'quoteVolume': '2524732882.04549930',
#   'openTime': 1646354915244,
#   'closeTime': 1646441315244,
#   'firstId': 1279418506,
#   'lastId': 1280887592,
#   'count': 1469087},
#  {'symbol': 'ETHUSDT',
#   'priceChange': '-157.00000000',
#   'priceChangePercent': '-5.689',
#   'weightedAvgPrice': '2687.99855191',
#   'prevClosePrice': '2759.55000000',
#   'lastPrice': '2602.68000000',
#   'lastQty': '0.69430000',
#   'bidPrice': '2602.67000000',
#   'bidQty': '32.56360000',
#   'askPrice': '2602.68000000',
#   'askQty': '18.71620000',
#   'openPrice': '2759.68000000',
#   'highPrice': '2760.53000000',
#   'lowPrice': '2573.00000000',
#   'volume': '546139.36000000',
#   'quoteVolume': '1468021808.82190400',
#   'openTime': 1646354915244,
#   'closeTime': 1646441315244,
#   'firstId': 774126046,
#   'lastId': 775045354,
#   'count': 919309},
#  {'symbol': 'HSRBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00041400',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'OAXETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00017780',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DNTETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00002801',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MCOETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00577200',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'ICNETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00166300',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MCOBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00021140',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'WTCBTC',
#   'priceChange': '0.00000052',
#   'priceChangePercent': '5.058',
#   'weightedAvgPrice': '0.00001082',
#   'prevClosePrice': '0.00001028',
#   'lastPrice': '0.00001080',
#   'lastQty': '179.00000000',
#   'bidPrice': '0.00001082',
#   'bidQty': '4930.00000000',
#   'askPrice': '0.00001087',
#   'askQty': '2712.00000000',
#   'openPrice': '0.00001028',
#   'highPrice': '0.00001175',
#   'lowPrice': '0.00001014',
#   'volume': '1671897.00000000',
#   'quoteVolume': '18.09107524',
#   'openTime': 1646354911920,
#   'closeTime': 1646441311920,
#   'firstId': 19192046,
#   'lastId': 19199386,
#   'count': 7341},
#  {'symbol': 'WTCETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00023700',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'LRCBTC',
#   'priceChange': '0.00000043',
#   'priceChangePercent': '2.357',
#   'weightedAvgPrice': '0.00001853',
#   'prevClosePrice': '0.00001826',
#   'lastPrice': '0.00001867',
#   'lastQty': '161.00000000',
#   'bidPrice': '0.00001866',
#   'bidQty': '727.00000000',
#   'askPrice': '0.00001868',
#   'askQty': '1795.00000000',
#   'openPrice': '0.00001824',
#   'highPrice': '0.00001887',
#   'lowPrice': '0.00001806',
#   'volume': '1239928.00000000',
#   'quoteVolume': '22.96987544',
#   'openTime': 1646354914611,
#   'closeTime': 1646441314611,
#   'firstId': 18401088,
#   'lastId': 18406935,
#   'count': 5848},
#  {'symbol': 'LRCETH',
#   'priceChange': '0.00000334',
#   'priceChangePercent': '1.214',
#   'weightedAvgPrice': '0.00028083',
#   'prevClosePrice': '0.00027610',
#   'lastPrice': '0.00027855',
#   'lastQty': '628.00000000',
#   'bidPrice': '0.00027809',
#   'bidQty': '413.00000000',
#   'askPrice': '0.00027905',
#   'askQty': '46.00000000',
#   'openPrice': '0.00027521',
#   'highPrice': '0.00028616',
#   'lowPrice': '0.00027505',
#   'volume': '253301.00000000',
#   'quoteVolume': '71.13442275',
#   'openTime': 1646354914536,
#   'closeTime': 1646441314536,
#   'firstId': 4270760,
#   'lastId': 4271732,
#   'count': 973},
#  {'symbol': 'QTUMBTC',
#   'priceChange': '-0.00000090',
#   'priceChangePercent': '-0.600',
#   'weightedAvgPrice': '0.00015073',
#   'prevClosePrice': '0.00014980',
#   'lastPrice': '0.00014900',
#   'lastQty': '0.90000000',
#   'bidPrice': '0.00014890',
#   'bidQty': '380.70000000',
#   'askPrice': '0.00014900',
#   'askQty': '2.60000000',
#   'openPrice': '0.00014990',
#   'highPrice': '0.00015330',
#   'lowPrice': '0.00014780',
#   'volume': '48497.70000000',
#   'quoteVolume': '7.31018007',
#   'openTime': 1646354913025,
#   'closeTime': 1646441313025,
#   'firstId': 22497168,
#   'lastId': 22503455,
#   'count': 6288},
#  {'symbol': 'YOYOBTC',
#   'priceChange': '0.00000009',
#   'priceChangePercent': '81.818',
#   'weightedAvgPrice': '0.00000019',
#   'prevClosePrice': '0.00000010',
#   'lastPrice': '0.00000020',
#   'lastQty': '163616.00000000',
#   'bidPrice': '0.00000020',
#   'bidQty': '1846575.00000000',
#   'askPrice': '0.00000021',
#   'askQty': '3508768.00000000',
#   'openPrice': '0.00000011',
#   'highPrice': '0.00000041',
#   'lowPrice': '0.00000010',
#   'volume': '871488654.00000000',
#   'quoteVolume': '169.19242965',
#   'openTime': 1646354914943,
#   'closeTime': 1646441314943,
#   'firstId': 7150855,
#   'lastId': 7175233,
#   'count': 24379},
#  {'symbol': 'OMGBTC',
#   'priceChange': '-0.00000080',
#   'priceChangePercent': '-0.797',
#   'weightedAvgPrice': '0.00010030',
#   'prevClosePrice': '0.00010040',
#   'lastPrice': '0.00009960',
#   'lastQty': '6.70000000',
#   'bidPrice': '0.00009930',
#   'bidQty': '2393.00000000',
#   'askPrice': '0.00009950',
#   'askQty': '351.40000000',
#   'openPrice': '0.00010040',
#   'highPrice': '0.00010230',
#   'lowPrice': '0.00009890',
#   'volume': '284037.80000000',
#   'quoteVolume': '28.48851294',
#   'openTime': 1646354914739,
#   'closeTime': 1646441314739,
#   'firstId': 24821775,
#   'lastId': 24825554,
#   'count': 3780},
#  {'symbol': 'OMGETH',
#   'priceChange': '-0.00003400',
#   'priceChangePercent': '-2.241',
#   'weightedAvgPrice': '0.00151740',
#   'prevClosePrice': '0.00151700',
#   'lastPrice': '0.00148300',
#   'lastQty': '44.50000000',
#   'bidPrice': '0.00148300',
#   'bidQty': '625.70000000',
#   'askPrice': '0.00148500',
#   'askQty': '22.50000000',
#   'openPrice': '0.00151700',
#   'highPrice': '0.00155300',
#   'lowPrice': '0.00148200',
#   'volume': '36841.00000000',
#   'quoteVolume': '55.90263030',
#   'openTime': 1646354887704,
#   'closeTime': 1646441287704,
#   'firstId': 5630710,
#   'lastId': 5631892,
#   'count': 1183},
#  {'symbol': 'ZRXBTC',
#   'priceChange': '-0.00000005',
#   'priceChangePercent': '-0.399',
#   'weightedAvgPrice': '0.00001251',
#   'prevClosePrice': '0.00001250',
#   'lastPrice': '0.00001247',
#   'lastQty': '132.00000000',
#   'bidPrice': '0.00001245',
#   'bidQty': '1333.00000000',
#   'askPrice': '0.00001247',
#   'askQty': '4351.00000000',
#   'openPrice': '0.00001252',
#   'highPrice': '0.00001279',
#   'lowPrice': '0.00001237',
#   'volume': '793509.00000000',
#   'quoteVolume': '9.93062447',
#   'openTime': 1646354911882,
#   'closeTime': 1646441311882,
#   'firstId': 24096865,
#   'lastId': 24098885,
#   'count': 2021},
#  {'symbol': 'ZRXETH',
#   'priceChange': '-0.00000340',
#   'priceChangePercent': '-1.793',
#   'weightedAvgPrice': '0.00018931',
#   'prevClosePrice': '0.00018910',
#   'lastPrice': '0.00018620',
#   'lastQty': '108.00000000',
#   'bidPrice': '0.00018590',
#   'bidQty': '1763.00000000',
#   'askPrice': '0.00018610',
#   'askQty': '77.00000000',
#   'openPrice': '0.00018960',
#   'highPrice': '0.00019460',
#   'lowPrice': '0.00018620',
#   'volume': '201029.00000000',
#   'quoteVolume': '38.05602340',
#   'openTime': 1646354912247,
#   'closeTime': 1646441312247,
#   'firstId': 5236805,
#   'lastId': 5237190,
#   'count': 386},
#  {'symbol': 'STRATBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00003085',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'STRATETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00105300',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SNGLSBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000013',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SNGLSETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00005306',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BQXBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00008703',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BQXETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00126350',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'KNCBTC',
#   'priceChange': '-0.00000237',
#   'priceChangePercent': '-3.665',
#   'weightedAvgPrice': '0.00006660',
#   'prevClosePrice': '0.00006463',
#   'lastPrice': '0.00006230',
#   'lastQty': '1.90000000',
#   'bidPrice': '0.00006223',
#   'bidQty': '12.50000000',
#   'askPrice': '0.00006230',
#   'askQty': '1203.60000000',
#   'openPrice': '0.00006467',
#   'highPrice': '0.00006986',
#   'lowPrice': '0.00006170',
#   'volume': '1256723.60000000',
#   'quoteVolume': '83.70282697',
#   'openTime': 1646354915019,
#   'closeTime': 1646441315019,
#   'firstId': 17712815,
#   'lastId': 17721365,
#   'count': 8551},
#  {'symbol': 'KNCETH',
#   'priceChange': '-0.00004890',
#   'priceChangePercent': '-4.990',
#   'weightedAvgPrice': '0.00102512',
#   'prevClosePrice': '0.00097640',
#   'lastPrice': '0.00093100',
#   'lastQty': '198.70000000',
#   'bidPrice': '0.00092910',
#   'bidQty': '21.10000000',
#   'askPrice': '0.00093050',
#   'askQty': '206.60000000',
#   'openPrice': '0.00097990',
#   'highPrice': '0.00106130',
#   'lowPrice': '0.00091900',
#   'volume': '868023.00000000',
#   'quoteVolume': '889.82936282',
#   'openTime': 1646354915230,
#   'closeTime': 1646441315230,
#   'firstId': 4426820,
#   'lastId': 4431538,
#   'count': 4719},
#  {'symbol': 'FUNBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000029',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'FUNETH',
#   'priceChange': '0.00000006',
#   'priceChangePercent': '1.648',
#   'weightedAvgPrice': '0.00000379',
#   'prevClosePrice': '0.00000363',
#   'lastPrice': '0.00000370',
#   'lastQty': '66432.00000000',
#   'bidPrice': '0.00000370',
#   'bidQty': '20706.00000000',
#   'askPrice': '0.00000371',
#   'askQty': '48625.00000000',
#   'openPrice': '0.00000364',
#   'highPrice': '0.00000402',
#   'lowPrice': '0.00000360',
#   'volume': '20433891.00000000',
#   'quoteVolume': '77.35947860',
#   'openTime': 1646354644174,
#   'closeTime': 1646441044174,
#   'firstId': 3000176,
#   'lastId': 3001499,
#   'count': 1324},
#  {'symbol': 'SNMBTC',
#   'priceChange': '-0.00000009',
#   'priceChangePercent': '-2.786',
#   'weightedAvgPrice': '0.00000326',
#   'prevClosePrice': '0.00000324',
#   'lastPrice': '0.00000314',
#   'lastQty': '2191.00000000',
#   'bidPrice': '0.00000314',
#   'bidQty': '33476.00000000',
#   'askPrice': '0.00000315',
#   'askQty': '1388.00000000',
#   'openPrice': '0.00000323',
#   'highPrice': '0.00000334',
#   'lowPrice': '0.00000314',
#   'volume': '1882379.00000000',
#   'quoteVolume': '6.13594057',
#   'openTime': 1646354910926,
#   'closeTime': 1646441310926,
#   'firstId': 9167391,
#   'lastId': 9169153,
#   'count': 1763},
#  {'symbol': 'SNMETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004986',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'NEOETH',
#   'priceChange': '-0.00024000',
#   'priceChangePercent': '-2.906',
#   'weightedAvgPrice': '0.00828192',
#   'prevClosePrice': '0.00827000',
#   'lastPrice': '0.00802000',
#   'lastQty': '18.60000000',
#   'bidPrice': '0.00802000',
#   'bidQty': '9.58000000',
#   'askPrice': '0.00803000',
#   'askQty': '146.55000000',
#   'openPrice': '0.00826000',
#   'highPrice': '0.00842000',
#   'lowPrice': '0.00800000',
#   'volume': '26130.93000000',
#   'quoteVolume': '216.41434310',
#   'openTime': 1646354915346,
#   'closeTime': 1646441315346,
#   'firstId': 10659922,
#   'lastId': 10661657,
#   'count': 1736},
#  {'symbol': 'IOTABTC',
#   'priceChange': '0.00000027',
#   'priceChangePercent': '1.517',
#   'weightedAvgPrice': '0.00001811',
#   'prevClosePrice': '0.00001780',
#   'lastPrice': '0.00001807',
#   'lastQty': '91.00000000',
#   'bidPrice': '0.00001806',
#   'bidQty': '730.00000000',
#   'askPrice': '0.00001808',
#   'askQty': '156.00000000',
#   'openPrice': '0.00001780',
#   'highPrice': '0.00001839',
#   'lowPrice': '0.00001771',
#   'volume': '716933.00000000',
#   'quoteVolume': '12.98141639',
#   'openTime': 1646354910324,
#   'closeTime': 1646441310324,
#   'firstId': 32614342,
#   'lastId': 32620147,
#   'count': 5806},
#  {'symbol': 'IOTAETH',
#   'priceChange': '0.00000030',
#   'priceChangePercent': '0.111',
#   'weightedAvgPrice': '0.00027249',
#   'prevClosePrice': '0.00026910',
#   'lastPrice': '0.00026980',
#   'lastQty': '222.00000000',
#   'bidPrice': '0.00026970',
#   'bidQty': '1424.00000000',
#   'askPrice': '0.00027000',
#   'askQty': '1423.00000000',
#   'openPrice': '0.00026950',
#   'highPrice': '0.00027820',
#   'lowPrice': '0.00026900',
#   'volume': '123524.00000000',
#   'quoteVolume': '33.65943590',
#   'openTime': 1646354913876,
#   'closeTime': 1646441313876,
#   'firstId': 7620753,
#   'lastId': 7621153,
#   'count': 401},
#  {'symbol': 'LINKBTC',
#   'priceChange': '-0.00000060',
#   'priceChangePercent': '-0.172',
#   'weightedAvgPrice': '0.00034734',
#   'prevClosePrice': '0.00034810',
#   'lastPrice': '0.00034740',
#   'lastQty': '9.94000000',
#   'bidPrice': '0.00034740',
#   'bidQty': '162.04000000',
#   'askPrice': '0.00034750',
#   'askQty': '8.10000000',
#   'openPrice': '0.00034800',
#   'highPrice': '0.00035330',
#   'lowPrice': '0.00034340',
#   'volume': '404219.11000000',
#   'quoteVolume': '140.40088108',
#   'openTime': 1646354914860,
#   'closeTime': 1646441314860,
#   'firstId': 75710725,
#   'lastId': 75727150,
#   'count': 16426},
#  {'symbol': 'LINKETH',
#   'priceChange': '-0.00007100',
#   'priceChangePercent': '-1.351',
#   'weightedAvgPrice': '0.00526326',
#   'prevClosePrice': '0.00526400',
#   'lastPrice': '0.00518400',
#   'lastQty': '3.00000000',
#   'bidPrice': '0.00518300',
#   'bidQty': '27.68000000',
#   'askPrice': '0.00518800',
#   'askQty': '138.92000000',
#   'openPrice': '0.00525500',
#   'highPrice': '0.00532400',
#   'lowPrice': '0.00517700',
#   'volume': '120845.67000000',
#   'quoteVolume': '636.04191157',
#   'openTime': 1646354906084,
#   'closeTime': 1646441306084,
#   'firstId': 15976106,
#   'lastId': 15979884,
#   'count': 3779},
#  {'symbol': 'XVGBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000024',
#   'prevClosePrice': '0.00000024',
#   'lastPrice': '0.00000024',
#   'lastQty': '76790.00000000',
#   'bidPrice': '0.00000024',
#   'bidQty': '17275551.00000000',
#   'askPrice': '0.00000025',
#   'askQty': '9829836.00000000',
#   'openPrice': '0.00000024',
#   'highPrice': '0.00000025',
#   'lowPrice': '0.00000023',
#   'volume': '21045691.00000000',
#   'quoteVolume': '5.02589574',
#   'openTime': 1646354867114,
#   'closeTime': 1646441267114,
#   'firstId': 28954937,
#   'lastId': 28955591,
#   'count': 655},
#  {'symbol': 'XVGETH',
#   'priceChange': '0.00000009',
#   'priceChangePercent': '2.550',
#   'weightedAvgPrice': '0.00000360',
#   'prevClosePrice': '0.00000353',
#   'lastPrice': '0.00000362',
#   'lastQty': '73717.00000000',
#   'bidPrice': '0.00000361',
#   'bidQty': '172893.00000000',
#   'askPrice': '0.00000363',
#   'askQty': '40529.00000000',
#   'openPrice': '0.00000353',
#   'highPrice': '0.00000373',
#   'lowPrice': '0.00000352',
#   'volume': '18520303.00000000',
#   'quoteVolume': '66.68777131',
#   'openTime': 1646354905815,
#   'closeTime': 1646441305815,
#   'firstId': 10602665,
#   'lastId': 10603488,
#   'count': 824},
#  {'symbol': 'SALTBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004250',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SALTETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00113800',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MDABTC',
#   'priceChange': '0.00000018',
#   'priceChangePercent': '1.822',
#   'weightedAvgPrice': '0.00001004',
#   'prevClosePrice': '0.00000988',
#   'lastPrice': '0.00001006',
#   'lastQty': '1131.00000000',
#   'bidPrice': '0.00001005',
#   'bidQty': '50.00000000',
#   'askPrice': '0.00001006',
#   'askQty': '167.00000000',
#   'openPrice': '0.00000988',
#   'highPrice': '0.00001024',
#   'lowPrice': '0.00000980',
#   'volume': '921520.00000000',
#   'quoteVolume': '9.24805238',
#   'openTime': 1646354914324,
#   'closeTime': 1646441314324,
#   'firstId': 14771206,
#   'lastId': 14775224,
#   'count': 4019},
#  {'symbol': 'MDAETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00181150',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MTLBTC',
#   'priceChange': '0.00000057',
#   'priceChangePercent': '1.612',
#   'weightedAvgPrice': '0.00003567',
#   'prevClosePrice': '0.00003535',
#   'lastPrice': '0.00003593',
#   'lastQty': '394.70000000',
#   'bidPrice': '0.00003592',
#   'bidQty': '496.20000000',
#   'askPrice': '0.00003597',
#   'askQty': '3.70000000',
#   'openPrice': '0.00003536',
#   'highPrice': '0.00003652',
#   'lowPrice': '0.00003491',
#   'volume': '921208.50000000',
#   'quoteVolume': '32.86253082',
#   'openTime': 1646354912851,
#   'closeTime': 1646441312851,
#   'firstId': 18800516,
#   'lastId': 18804109,
#   'count': 3594},
#  {'symbol': 'MTLETH',
#   'priceChange': '0.00000180',
#   'priceChangePercent': '0.337',
#   'weightedAvgPrice': '0.00054101',
#   'prevClosePrice': '0.00053490',
#   'lastPrice': '0.00053620',
#   'lastQty': '886.60000000',
#   'bidPrice': '0.00053620',
#   'bidQty': '0.10000000',
#   'askPrice': '0.00053750',
#   'askQty': '38.70000000',
#   'openPrice': '0.00053440',
#   'highPrice': '0.00054770',
#   'lowPrice': '0.00053090',
#   'volume': '748247.30000000',
#   'quoteVolume': '404.80964112',
#   'openTime': 1646354912594,
#   'closeTime': 1646441312594,
#   'firstId': 2832653,
#   'lastId': 2835059,
#   'count': 2407},
#  {'symbol': 'SUBBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000457',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SUBETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00012334',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'EOSBTC',
#   'priceChange': '0.00000040',
#   'priceChangePercent': '0.789',
#   'weightedAvgPrice': '0.00005068',
#   'prevClosePrice': '0.00005080',
#   'lastPrice': '0.00005110',
#   'lastQty': '5107.30000000',
#   'bidPrice': '0.00005100',
#   'bidQty': '3952.60000000',
#   'askPrice': '0.00005110',
#   'askQty': '548.70000000',
#   'openPrice': '0.00005070',
#   'highPrice': '0.00005150',
#   'lowPrice': '0.00005000',
#   'volume': '356658.70000000',
#   'quoteVolume': '18.07404999',
#   'openTime': 1646354912378,
#   'closeTime': 1646441312378,
#   'firstId': 71276081,
#   'lastId': 71279041,
#   'count': 2961},
#  {'symbol': 'SNTBTC',
#   'priceChange': '0.00000007',
#   'priceChangePercent': '5.385',
#   'weightedAvgPrice': '0.00000135',
#   'prevClosePrice': '0.00000131',
#   'lastPrice': '0.00000137',
#   'lastQty': '219.00000000',
#   'bidPrice': '0.00000136',
#   'bidQty': '97902.00000000',
#   'askPrice': '0.00000137',
#   'askQty': '58483.00000000',
#   'openPrice': '0.00000130',
#   'highPrice': '0.00000139',
#   'lowPrice': '0.00000128',
#   'volume': '9214712.00000000',
#   'quoteVolume': '12.40378660',
#   'openTime': 1646354912261,
#   'closeTime': 1646441312261,
#   'firstId': 10877275,
#   'lastId': 10881274,
#   'count': 4000},
#  {'symbol': 'ETCETH',
#   'priceChange': '-0.00030000',
#   'priceChangePercent': '-2.783',
#   'weightedAvgPrice': '0.01064742',
#   'prevClosePrice': '0.01082000',
#   'lastPrice': '0.01048000',
#   'lastQty': '42.45000000',
#   'bidPrice': '0.01047000',
#   'bidQty': '101.59000000',
#   'askPrice': '0.01049000',
#   'askQty': '112.05000000',
#   'openPrice': '0.01078000',
#   'highPrice': '0.01088000',
#   'lowPrice': '0.01041000',
#   'volume': '13567.55000000',
#   'quoteVolume': '144.45947030',
#   'openTime': 1646354915094,
#   'closeTime': 1646441315094,
#   'firstId': 7527017,
#   'lastId': 7528509,
#   'count': 1493},
#  {'symbol': 'ETCBTC',
#   'priceChange': '-0.00001300',
#   'priceChangePercent': '-1.821',
#   'weightedAvgPrice': '0.00070212',
#   'prevClosePrice': '0.00071500',
#   'lastPrice': '0.00070100',
#   'lastQty': '0.33000000',
#   'bidPrice': '0.00070100',
#   'bidQty': '358.83000000',
#   'askPrice': '0.00070300',
#   'askQty': '240.02000000',
#   'openPrice': '0.00071400',
#   'highPrice': '0.00071500',
#   'lowPrice': '0.00069200',
#   'volume': '67999.97000000',
#   'quoteVolume': '47.74447473',
#   'openTime': 1646354915120,
#   'closeTime': 1646441315120,
#   'firstId': 38230465,
#   'lastId': 38236244,
#   'count': 5780},
#  {'symbol': 'MTHBTC',
#   'priceChange': '0.00000007',
#   'priceChangePercent': '18.919',
#   'weightedAvgPrice': '0.00000047',
#   'prevClosePrice': '0.00000037',
#   'lastPrice': '0.00000044',
#   'lastQty': '767657.00000000',
#   'bidPrice': '0.00000044',
#   'bidQty': '258252.00000000',
#   'askPrice': '0.00000045',
#   'askQty': '945651.00000000',
#   'openPrice': '0.00000037',
#   'highPrice': '0.00000063',
#   'lowPrice': '0.00000034',
#   'volume': '102455278.00000000',
#   'quoteVolume': '48.11635582',
#   'openTime': 1646354914885,
#   'closeTime': 1646441314885,
#   'firstId': 7359080,
#   'lastId': 7367770,
#   'count': 8691},
#  {'symbol': 'MTHETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004135',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'ENGBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00006200',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'ENGETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00186480',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DNTBTC',
#   'priceChange': '0.00000004',
#   'priceChangePercent': '2.367',
#   'weightedAvgPrice': '0.00000183',
#   'prevClosePrice': '0.00000169',
#   'lastPrice': '0.00000173',
#   'lastQty': '2841.00000000',
#   'bidPrice': '0.00000172',
#   'bidQty': '137064.00000000',
#   'askPrice': '0.00000173',
#   'askQty': '123395.00000000',
#   'openPrice': '0.00000169',
#   'highPrice': '0.00000197',
#   'lowPrice': '0.00000168',
#   'volume': '15591906.00000000',
#   'quoteVolume': '28.52393618',
#   'openTime': 1646354907542,
#   'closeTime': 1646441307542,
#   'firstId': 13314589,
#   'lastId': 13318941,
#   'count': 4353},
#  {'symbol': 'ZECBTC',
#   'priceChange': '-0.00007200',
#   'priceChangePercent': '-2.376',
#   'weightedAvgPrice': '0.00300524',
#   'prevClosePrice': '0.00302800',
#   'lastPrice': '0.00295800',
#   'lastQty': '0.50000000',
#   'bidPrice': '0.00295700',
#   'bidQty': '10.70700000',
#   'askPrice': '0.00296000',
#   'askQty': '13.45600000',
#   'openPrice': '0.00303000',
#   'highPrice': '0.00312200',
#   'lowPrice': '0.00292100',
#   'volume': '21196.98600000',
#   'quoteVolume': '63.70213526',
#   'openTime': 1646354913123,
#   'closeTime': 1646441313123,
#   'firstId': 23741664,
#   'lastId': 23751924,
#   'count': 10261},
#  {'symbol': 'ZECETH',
#   'priceChange': '-0.00174000',
#   'priceChangePercent': '-3.788',
#   'weightedAvgPrice': '0.04557011',
#   'prevClosePrice': '0.04580000',
#   'lastPrice': '0.04419000',
#   'lastQty': '1.47600000',
#   'bidPrice': '0.04413000',
#   'bidQty': '13.82400000',
#   'askPrice': '0.04419000',
#   'askQty': '15.37300000',
#   'openPrice': '0.04593000',
#   'highPrice': '0.04735000',
#   'lowPrice': '0.04383000',
#   'volume': '2315.14500000',
#   'quoteVolume': '105.50140229',
#   'openTime': 1646354913573,
#   'closeTime': 1646441313573,
#   'firstId': 3359773,
#   'lastId': 3361132,
#   'count': 1360},
#  {'symbol': 'BNTBTC',
#   'priceChange': '0.00000058',
#   'priceChangePercent': '1.039',
#   'weightedAvgPrice': '0.00005612',
#   'prevClosePrice': '0.00005590',
#   'lastPrice': '0.00005642',
#   'lastQty': '7.10000000',
#   'bidPrice': '0.00005629',
#   'bidQty': '19.80000000',
#   'askPrice': '0.00005639',
#   'askQty': '95.00000000',
#   'openPrice': '0.00005584',
#   'highPrice': '0.00005689',
#   'lowPrice': '0.00005542',
#   'volume': '59240.10000000',
#   'quoteVolume': '3.32436957',
#   'openTime': 1646354912523,
#   'closeTime': 1646441312523,
#   'firstId': 7308376,
#   'lastId': 7310114,
#   'count': 1739},
#  {'symbol': 'ASTBTC',
#   'priceChange': '-0.00000003',
#   'priceChangePercent': '-0.867',
#   'weightedAvgPrice': '0.00000353',
#   'prevClosePrice': '0.00000348',
#   'lastPrice': '0.00000343',
#   'lastQty': '339.00000000',
#   'bidPrice': '0.00000341',
#   'bidQty': '11601.00000000',
#   'askPrice': '0.00000343',
#   'askQty': '31544.00000000',
#   'openPrice': '0.00000346',
#   'highPrice': '0.00000370',
#   'lowPrice': '0.00000340',
#   'volume': '1268671.00000000',
#   'quoteVolume': '4.47678283',
#   'openTime': 1646354906809,
#   'closeTime': 1646441306809,
#   'firstId': 14174294,
#   'lastId': 14176002,
#   'count': 1709},
#  {'symbol': 'ASTETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00006960',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DASHBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00228320',
#   'prevClosePrice': '0.00226500',
#   'lastPrice': '0.00226000',
#   'lastQty': '0.09600000',
#   'bidPrice': '0.00225900',
#   'bidQty': '22.49500000',
#   'askPrice': '0.00226200',
#   'askQty': '12.56900000',
#   'openPrice': '0.00226000',
#   'highPrice': '0.00230700',
#   'lowPrice': '0.00225000',
#   'volume': '6339.46000000',
#   'quoteVolume': '14.47425726',
#   'openTime': 1646354911947,
#   'closeTime': 1646441311947,
#   'firstId': 25233633,
#   'lastId': 25237374,
#   'count': 3742},
#  {'symbol': 'DASHETH',
#   'priceChange': '-0.00045000',
#   'priceChangePercent': '-1.318',
#   'weightedAvgPrice': '0.03449821',
#   'prevClosePrice': '0.03417000',
#   'lastPrice': '0.03369000',
#   'lastQty': '1.85400000',
#   'bidPrice': '0.03372000',
#   'bidQty': '5.69100000',
#   'askPrice': '0.03377000',
#   'askQty': '0.58300000',
#   'openPrice': '0.03414000',
#   'highPrice': '0.03508000',
#   'lowPrice': '0.03369000',
#   'volume': '1454.47500000',
#   'quoteVolume': '50.17678561',
#   'openTime': 1646354905650,
#   'closeTime': 1646441305650,
#   'firstId': 3632241,
#   'lastId': 3633139,
#   'count': 899},
#  {'symbol': 'OAXBTC',
#   'priceChange': '0.00000002',
#   'priceChangePercent': '0.840',
#   'weightedAvgPrice': '0.00000244',
#   'prevClosePrice': '0.00000240',
#   'lastPrice': '0.00000240',
#   'lastQty': '170.00000000',
#   'bidPrice': '0.00000239',
#   'bidQty': '1038.00000000',
#   'askPrice': '0.00000240',
#   'askQty': '15961.00000000',
#   'openPrice': '0.00000238',
#   'highPrice': '0.00000249',
#   'lowPrice': '0.00000235',
#   'volume': '2005356.00000000',
#   'quoteVolume': '4.88910492',
#   'openTime': 1646354707781,
#   'closeTime': 1646441107781,
#   'firstId': 8710157,
#   'lastId': 8711113,
#   'count': 957},
#  {'symbol': 'ICNBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00005742',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BTGBTC',
#   'priceChange': '0.00002400',
#   'priceChangePercent': '3.239',
#   'weightedAvgPrice': '0.00075553',
#   'prevClosePrice': '0.00074000',
#   'lastPrice': '0.00076500',
#   'lastQty': '7.95000000',
#   'bidPrice': '0.00076300',
#   'bidQty': '34.83000000',
#   'askPrice': '0.00076500',
#   'askQty': '8.76000000',
#   'openPrice': '0.00074100',
#   'highPrice': '0.00077700',
#   'lowPrice': '0.00073700',
#   'volume': '3915.90000000',
#   'quoteVolume': '2.95856357',
#   'openTime': 1646354897482,
#   'closeTime': 1646441297482,
#   'firstId': 14827910,
#   'lastId': 14829283,
#   'count': 1374},
#  {'symbol': 'BTGETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.05274500',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'EVXBTC',
#   'priceChange': '-0.00000113',
#   'priceChangePercent': '-29.199',
#   'weightedAvgPrice': '0.00000329',
#   'prevClosePrice': '0.00000386',
#   'lastPrice': '0.00000274',
#   'lastQty': '313.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000387',
#   'highPrice': '0.00000387',
#   'lowPrice': '0.00000272',
#   'volume': '7918941.00000000',
#   'quoteVolume': '26.05634789',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': 10790699,
#   'lastId': 10797831,
#   'count': 7133},
#  {'symbol': 'EVXETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00062490',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'REQBTC',
#   'priceChange': '0.00000009',
#   'priceChangePercent': '1.748',
#   'weightedAvgPrice': '0.00000518',
#   'prevClosePrice': '0.00000517',
#   'lastPrice': '0.00000524',
#   'lastQty': '986.00000000',
#   'bidPrice': '0.00000524',
#   'bidQty': '349.00000000',
#   'askPrice': '0.00000526',
#   'askQty': '14102.00000000',
#   'openPrice': '0.00000515',
#   'highPrice': '0.00000532',
#   'lowPrice': '0.00000509',
#   'volume': '1938467.00000000',
#   'quoteVolume': '10.03515817',
#   'openTime': 1646354913853,
#   'closeTime': 1646441313853,
#   'firstId': 11724428,
#   'lastId': 11727023,
#   'count': 2596},
#  {'symbol': 'REQETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004995',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'VIBBTC',
#   'priceChange': '-0.00000001',
#   'priceChangePercent': '-1.562',
#   'weightedAvgPrice': '0.00000064',
#   'prevClosePrice': '0.00000064',
#   'lastPrice': '0.00000063',
#   'lastQty': '84804.00000000',
#   'bidPrice': '0.00000063',
#   'bidQty': '558686.00000000',
#   'askPrice': '0.00000064',
#   'askQty': '512069.00000000',
#   'openPrice': '0.00000064',
#   'highPrice': '0.00000066',
#   'lowPrice': '0.00000062',
#   'volume': '5521772.00000000',
#   'quoteVolume': '3.55233639',
#   'openTime': 1646354907226,
#   'closeTime': 1646441307226,
#   'firstId': 8538205,
#   'lastId': 8538947,
#   'count': 743},
#  {'symbol': 'VIBETH',
#   'priceChange': '-0.00000024',
#   'priceChangePercent': '-2.479',
#   'weightedAvgPrice': '0.00000970',
#   'prevClosePrice': '0.00000968',
#   'lastPrice': '0.00000944',
#   'lastQty': '565.00000000',
#   'bidPrice': '0.00000941',
#   'bidQty': '6376.00000000',
# ...
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.51700000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'TRBBTC',
#   'priceChange': '-0.00000200',
#   'priceChangePercent': '-0.434',
#   'weightedAvgPrice': '0.00046521',
#   'prevClosePrice': '0.00046200',
#   'lastPrice': '0.00045900',
#   'lastQty': '2.38000000',
#   'bidPrice': '0.00045700',
#   'bidQty': '108.76000000',
#   'askPrice': '0.00045900',
#   'askQty': '47.59000000',
#   'openPrice': '0.00046100',
#   'highPrice': '0.00046900',
#   'lowPrice': '0.00045700',
#   'volume': '4891.73000000',
#   'quoteVolume': '2.27570279',
#   'openTime': 1646354898873,
#   'closeTime': 1646441298873,
#   'firstId': 4236515,
#   'lastId': 4237733,
#   'count': 1219},
#  {'symbol': 'TRBBUSD',
#   'priceChange': '-1.43000000',
#   'priceChangePercent': '-7.432',
#   'weightedAvgPrice': '18.82677990',
#   'prevClosePrice': '19.25000000',
#   'lastPrice': '17.81000000',
#   'lastQty': '21.28000000',
#   'bidPrice': '17.77000000',
#   'bidQty': '50.60000000',
#   'askPrice': '17.82000000',
#   'askQty': '21.74000000',
#   'openPrice': '19.24000000',
#   'highPrice': '19.47000000',
#   'lowPrice': '17.68000000',
#   'volume': '4071.61000000',
#   'quoteVolume': '76655.30530000',
#   'openTime': 1646354896709,
#   'closeTime': 1646441296709,
#   'firstId': 1690305,
#   'lastId': 1691231,
#   'count': 927},
#  {'symbol': 'TRBUSDT',
#   'priceChange': '-1.44000000',
#   'priceChangePercent': '-7.481',
#   'weightedAvgPrice': '18.94212128',
#   'prevClosePrice': '19.26000000',
#   'lastPrice': '17.81000000',
#   'lastQty': '0.61000000',
#   'bidPrice': '17.80000000',
#   'bidQty': '15.08000000',
#   'askPrice': '17.81000000',
#   'askQty': '4.98000000',
#   'openPrice': '19.25000000',
#   'highPrice': '19.53000000',
#   'lowPrice': '17.72000000',
#   'volume': '87054.81000000',
#   'quoteVolume': '1649002.76860000',
#   'openTime': 1646354912059,
#   'closeTime': 1646441312059,
#   'firstId': 17967478,
#   'lastId': 17980414,
#   'count': 12937},
#  {'symbol': 'ETHNGN',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '805670.00000000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DOTBIDR',
#   'priceChange': '-13782.00',
#   'priceChangePercent': '-5.473',
#   'weightedAvgPrice': '247265.50',
#   'prevClosePrice': '251573.00',
#   'lastPrice': '238049.00',
#   'lastQty': '1.96000000',
#   'bidPrice': '237508.00',
#   'bidQty': '60.73000000',
#   'askPrice': '237991.00',
#   'askQty': '60.69000000',
#   'openPrice': '251831.00',
#   'highPrice': '252416.00',
#   'lowPrice': '236538.00',
#   'volume': '7360.35000000',
#   'quoteVolume': '1819960591.03',
#   'openTime': 1646354914686,
#   'closeTime': 1646441314686,
#   'firstId': 1187626,
#   'lastId': 1188492,
#   'count': 867},
#  {'symbol': 'LINKAUD',
#   'priceChange': '-1.48000000',
#   'priceChangePercent': '-7.452',
#   'weightedAvgPrice': '19.24379115',
#   'prevClosePrice': '19.95000000',
#   'lastPrice': '18.38000000',
#   'lastQty': '47.79000000',
#   'bidPrice': '18.38000000',
#   'bidQty': '185.37000000',
#   'askPrice': '18.40000000',
#   'askQty': '11.01000000',
#   'openPrice': '19.86000000',
#   'highPrice': '19.86000000',
#   'lowPrice': '18.32000000',
#   'volume': '11282.89000000',
#   'quoteVolume': '217125.57870000',
#   'openTime': 1646354915323,
#   'closeTime': 1646441315323,
#   'firstId': 459098,
#   'lastId': 459427,
#   'count': 330},
#  {'symbol': 'SXPAUD',
#   'priceChange': '0.10100000',
#   'priceChangePercent': '5.716',
#   'weightedAvgPrice': '1.83126335',
#   'prevClosePrice': '1.75400000',
#   'lastPrice': '1.86800000',
#   'lastQty': '6.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '1.76700000',
#   'highPrice': '1.92700000',
#   'lowPrice': '1.73100000',
#   'volume': '41982.90000000',
#   'quoteVolume': '76881.74600000',
#   'openTime': 1643252401360,
#   'closeTime': 1643338801360,
#   'firstId': 446252,
#   'lastId': 446608,
#   'count': 357},
#  {'symbol': 'BZRXBNB',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00514000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BZRXBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000463',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BZRXBUSD',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.21640000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BZRXUSDT',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.21560000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640512777193,
#   'closeTime': 1640599177193,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'WBTCBTC',
#   'priceChange': '0.00050000',
#   'priceChangePercent': '0.050',
#   'weightedAvgPrice': '1.00049455',
#   'prevClosePrice': '1.00000000',
#   'lastPrice': '1.00050000',
#   'lastQty': '0.00457000',
#   'bidPrice': '1.00040000',
#   'bidQty': '6.83261000',
#   'askPrice': '1.00090000',
#   'askQty': '0.40018000',
#   'openPrice': '1.00000000',
#   'highPrice': '1.00180000',
#   'lowPrice': '0.99990000',
#   'volume': '260.17978000',
#   'quoteVolume': '260.30845133',
#   'openTime': 1646354894000,
#   'closeTime': 1646441294000,
#   'firstId': 2696171,
#   'lastId': 2697215,
#   'count': 1045},
#  {'symbol': 'WBTCETH',
#   'priceChange': '-0.21000000',
#   'priceChangePercent': '-1.387',
#   'weightedAvgPrice': '15.16363008',
#   'prevClosePrice': '15.14000000',
#   'lastPrice': '14.93000000',
#   'lastQty': '0.02235000',
#   'bidPrice': '14.91000000',
#   'bidQty': '0.12893000',
#   'askPrice': '14.94000000',
#   'askQty': '0.61668000',
#   'openPrice': '15.14000000',
#   'highPrice': '15.33000000',
#   'lowPrice': '14.90000000',
#   'volume': '25.56529000',
#   'quoteVolume': '387.66260040',
#   'openTime': 1646354905724,
#   'closeTime': 1646441305724,
#   'firstId': 2566798,
#   'lastId': 2569166,
#   'count': 2369},
#  {'symbol': 'SUSHIBNB',
#   'priceChange': '-0.00005000',
#   'priceChangePercent': '-0.615',
#   'weightedAvgPrice': '0.00816034',
#   'prevClosePrice': '0.00813000',
#   'lastPrice': '0.00808000',
#   'lastQty': '393.90000000',
#   'bidPrice': '0.00807000',
#   'bidQty': '947.80000000',
#   'askPrice': '0.00809000',
#   'askQty': '733.50000000',
#   'openPrice': '0.00813000',
#   'highPrice': '0.00830000',
#   'lowPrice': '0.00805000',
#   'volume': '76812.20000000',
#   'quoteVolume': '626.81329600',
#   'openTime': 1646354890112,
#   'closeTime': 1646441290112,
#   'firstId': 2354524,
#   'lastId': 2355697,
#   'count': 1174},
#  {'symbol': 'SUSHIBTC',
#   'priceChange': '-0.00000020',
#   'priceChangePercent': '-0.259',
#   'weightedAvgPrice': '0.00007784',
#   'prevClosePrice': '0.00007710',
#   'lastPrice': '0.00007690',
#   'lastQty': '54.30000000',
#   'bidPrice': '0.00007670',
#   'bidQty': '2505.30000000',
#   'askPrice': '0.00007690',
#   'askQty': '1168.70000000',
#   'openPrice': '0.00007710',
#   'highPrice': '0.00007930',
#   'lowPrice': '0.00007660',
#   'volume': '247084.40000000',
#   'quoteVolume': '19.23390147',
#   'openTime': 1646354912275,
#   'closeTime': 1646441312275,
#   'firstId': 15865769,
#   'lastId': 15870178,
#   'count': 4410},
#  {'symbol': 'SUSHIBUSD',
#   'priceChange': '-0.23700000',
#   'priceChangePercent': '-7.358',
#   'weightedAvgPrice': '3.16045765',
#   'prevClosePrice': '3.21700000',
#   'lastPrice': '2.98400000',
#   'lastQty': '127.00000000',
#   'bidPrice': '2.98300000',
#   'bidQty': '578.50000000',
#   'askPrice': '2.98700000',
#   'askQty': '16.70000000',
#   'openPrice': '3.22100000',
#   'highPrice': '3.28300000',
#   'lowPrice': '2.97100000',
#   'volume': '241949.00000000',
#   'quoteVolume': '764669.56820000',
#   'openTime': 1646354912094,
#   'closeTime': 1646441312094,
#   'firstId': 7812804,
#   'lastId': 7816902,
#   'count': 4099},
#  {'symbol': 'SUSHIUSDT',
#   'priceChange': '-0.23900000',
#   'priceChangePercent': '-7.415',
#   'weightedAvgPrice': '3.16220989',
#   'prevClosePrice': '3.21900000',
#   'lastPrice': '2.98400000',
#   'lastQty': '50.40000000',
#   'bidPrice': '2.98400000',
#   'bidQty': '172.10000000',
#   'askPrice': '2.98600000',
#   'askQty': '1126.10000000',
#   'openPrice': '3.22300000',
#   'highPrice': '3.28200000',
#   'lowPrice': '2.96900000',
#   'volume': '4697033.30000000',
#   'quoteVolume': '14853005.14670000',
#   'openTime': 1646354915135,
#   'closeTime': 1646441315135,
#   'firstId': 74669129,
#   'lastId': 74714146,
#   'count': 45018},
#  {'symbol': 'YFIIBNB',
#   'priceChange': '0.01000000',
#   'priceChangePercent': '0.194',
#   'weightedAvgPrice': '5.35718382',
#   'prevClosePrice': '5.17000000',
#   'lastPrice': '5.17000000',
#   'lastQty': '0.04180000',
#   'bidPrice': '5.17000000',
#   'bidQty': '0.09600000',
#   'askPrice': '5.19000000',
#   'askQty': '0.60000000',
#   'openPrice': '5.16000000',
#   'highPrice': '5.56000000',
#   'lowPrice': '5.12000000',
#   'volume': '93.81800000',
#   'quoteVolume': '502.60027200',
#   'openTime': 1646354703813,
#   'closeTime': 1646441103813,
#   'firstId': 458668,
#   'lastId': 459021,
#   'count': 354},
#  {'symbol': 'YFIIBTC',
#   'priceChange': '0.00020000',
#   'priceChangePercent': '0.409',
#   'weightedAvgPrice': '0.04990229',
#   'prevClosePrice': '0.04890000',
#   'lastPrice': '0.04910000',
#   'lastQty': '0.03180000',
#   'bidPrice': '0.04920000',
#   'bidQty': '0.11530000',
#   'askPrice': '0.04930000',
#   'askQty': '0.70270000',
#   'openPrice': '0.04890000',
#   'highPrice': '0.05160000',
#   'lowPrice': '0.04830000',
#   'volume': '97.12770000',
#   'quoteVolume': '4.84689476',
#   'openTime': 1646354911114,
#   'closeTime': 1646441311114,
#   'firstId': 6174934,
#   'lastId': 6176146,
#   'count': 1213},
#  {'symbol': 'YFIIBUSD',
#   'priceChange': '-124.00000000',
#   'priceChangePercent': '-6.087',
#   'weightedAvgPrice': '2023.61719888',
#   'prevClosePrice': '2039.00000000',
#   'lastPrice': '1913.00000000',
#   'lastQty': '0.01710000',
#   'bidPrice': '1912.00000000',
#   'bidQty': '0.16530000',
#   'askPrice': '1914.00000000',
#   'askQty': '0.18000000',
#   'openPrice': '2037.00000000',
#   'highPrice': '2149.00000000',
#   'lowPrice': '1903.00000000',
#   'volume': '36.04770000',
#   'quoteVolume': '72946.74570000',
#   'openTime': 1646354909121,
#   'closeTime': 1646441309121,
#   'firstId': 1709103,
#   'lastId': 1710298,
#   'count': 1196},
#  {'symbol': 'YFIIUSDT',
#   'priceChange': '-129.00000000',
#   'priceChangePercent': '-6.317',
#   'weightedAvgPrice': '2032.19185261',
#   'prevClosePrice': '2043.00000000',
#   'lastPrice': '1913.00000000',
#   'lastQty': '0.00550000',
#   'bidPrice': '1912.00000000',
#   'bidQty': '0.36930000',
#   'askPrice': '1913.00000000',
#   'askQty': '0.01360000',
#   'openPrice': '2042.00000000',
#   'highPrice': '2149.00000000',
#   'lowPrice': '1902.00000000',
#   'volume': '773.06740000',
#   'quoteVolume': '1571021.27180000',
#   'openTime': 1646354911874,
#   'closeTime': 1646441311874,
#   'firstId': 24603233,
#   'lastId': 24617981,
#   'count': 14749},
#  {'symbol': 'KSMBNB',
#   'priceChange': '-0.00410000',
#   'priceChangePercent': '-1.258',
#   'weightedAvgPrice': '0.32645747',
#   'prevClosePrice': '0.32750000',
#   'lastPrice': '0.32190000',
#   'lastQty': '0.05300000',
#   'bidPrice': '0.32010000',
#   'bidQty': '0.34000000',
#   'askPrice': '0.32190000',
#   'askQty': '8.36600000',
#   'openPrice': '0.32600000',
#   'highPrice': '0.33220000',
#   'lowPrice': '0.31840000',
#   'volume': '594.22100000',
#   'quoteVolume': '193.98788720',
#   'openTime': 1646354768767,
#   'closeTime': 1646441168767,
#   'firstId': 1063479,
#   'lastId': 1063775,
#   'count': 297},
#  {'symbol': 'KSMBTC',
#   'priceChange': '-0.00003600',
#   'priceChangePercent': '-1.166',
#   'weightedAvgPrice': '0.00310306',
#   'prevClosePrice': '0.00308800',
#   'lastPrice': '0.00305100',
#   'lastQty': '1.72900000',
#   'bidPrice': '0.00304900',
#   'bidQty': '7.49500000',
#   'askPrice': '0.00305200',
#   'askQty': '0.15000000',
#   'openPrice': '0.00308700',
#   'highPrice': '0.00314700',
#   'lowPrice': '0.00304400',
#   'volume': '3488.77100000',
#   'quoteVolume': '10.82585674',
#   'openTime': 1646354910424,
#   'closeTime': 1646441310424,
#   'firstId': 8027987,
#   'lastId': 8032133,
#   'count': 4147},
#  {'symbol': 'KSMBUSD',
#   'priceChange': '-10.20000000',
#   'priceChangePercent': '-7.938',
#   'weightedAvgPrice': '126.01659700',
#   'prevClosePrice': '129.00000000',
#   'lastPrice': '118.30000000',
#   'lastQty': '0.70500000',
#   'bidPrice': '118.50000000',
#   'bidQty': '11.28300000',
#   'askPrice': '118.70000000',
#   'askQty': '2.49600000',
#   'openPrice': '128.50000000',
#   'highPrice': '131.20000000',
#   'lowPrice': '117.80000000',
#   'volume': '2750.28700000',
#   'quoteVolume': '346581.80850000',
#   'openTime': 1646354906333,
#   'closeTime': 1646441306333,
#   'firstId': 6446863,
#   'lastId': 6449218,
#   'count': 2356},
#  {'symbol': 'KSMUSDT',
#   'priceChange': '-10.30000000',
#   'priceChangePercent': '-7.997',
#   'weightedAvgPrice': '126.11611680',
#   'prevClosePrice': '128.70000000',
#   'lastPrice': '118.50000000',
#   'lastQty': '21.18600000',
#   'bidPrice': '118.50000000',
#   'bidQty': '20.69300000',
#   'askPrice': '118.60000000',
#   'askQty': '4.97800000',
#   'openPrice': '128.80000000',
#   'highPrice': '131.30000000',
#   'lowPrice': '117.80000000',
#   'volume': '35042.44800000',
#   'quoteVolume': '4419417.46510000',
#   'openTime': 1646354912446,
#   'closeTime': 1646441312446,
#   'firstId': 52365041,
#   'lastId': 52390843,
#   'count': 25803},
#  {'symbol': 'EGLDBNB',
#   'priceChange': '-0.00820000',
#   'priceChangePercent': '-2.282',
#   'weightedAvgPrice': '0.35554100',
#   'prevClosePrice': '0.35940000',
#   'lastPrice': '0.35120000',
#   'lastQty': '1.74000000',
#   'bidPrice': '0.35110000',
#   'bidQty': '6.20000000',
#   'askPrice': '0.35180000',
#   'askQty': '1.87000000',
#   'openPrice': '0.35940000',
#   'highPrice': '0.36740000',
#   'lowPrice': '0.34620000',
#   'volume': '1687.18000000',
#   'quoteVolume': '599.86166600',
#   'openTime': 1646354912054,
#   'closeTime': 1646441312054,
#   'firstId': 2201219,
#   'lastId': 2202561,
#   'count': 1343},
#  ...]

# %%
from tensortrade.binance.strategy import Binance_strategy
strategy = Binance_strategy(crypto=crypto)
strategy.get_moving_pairs()
# Out:
# (Empty DataFrame
#  Columns: [symbol, priceChangePercent, lastPrice, volume, bidAskQtyChangePercent, count]
#  Index: [],
#  None,
#  None)

# %%
crypto.pair.info.pair
# Out:
# 'SCRTUSDT'

# %%
from tensortrade.binance.futures import Binance_futures
futures = Binance_futures(futures_client=crypto.futures_client)
futures1 = futures.filter_buy_sell_ratio(symbol='BTCUSDT', period='5m')
futures2 = futures.filter_top_long_short_accounts(symbol='DOTUSDT', period='5m')
futures2

# %%
results = futures_client.get_top_long_short_accounts(symbol='DOTUSDT', period='5m')
df = pd.DataFrame([result.__dict__ for result in results])[['timestamp', 'longShortRatio']]
df = df.rename(columns={'timestamp': 'time', 'longShortRatio': 'long_short_ratio'})
df = df.set_index('time').sort_index().reset_index(drop=True)
df

# %%
interest = futures_client.get_top_long_short_accounts(symbol='BTCUSDT', period='5m')
df = pd.DataFrame([interest.__dict__ for interest in interest])
df

# %%
interest = futures_client.get_open_interest_stats(symbol='BTCUSDT', period='5m')
df = pd.DataFrame([interest.__dict__ for interest in interest])
df
