# %% [markdown]
# Cryptocurrency trading bot.

# %% [markdown]
# Library imports.

# %%
import pandas as pd, random, time

from binance.exceptions import BinanceAPIException
from tensortrade.binance import Binance

# %% [markdown]
# Program parameters.

# %%
intervals = ['1m']
symbol = 'BTCUSDT'
DELAY = 5
count = 1

# %% [markdown]
# Program initialization.

# %%
crypto = Binance(use_futures=False)
spot_client = crypto.spot_client
futures_client = crypto.futures_client

crypto.make_pair(symbol, intervals=intervals, download=True)
pair = crypto.pair

# %%
spot_client.get_ticker()
# Out:
# [{'symbol': 'ETHBTC',
#   'priceChange': '-0.00058900',
#   'priceChangePercent': '-0.887',
#   'weightedAvgPrice': '0.06595845',
#   'prevClosePrice': '0.06640600',
#   'lastPrice': '0.06581300',
#   'lastQty': '7.44720000',
#   'bidPrice': '0.06581300',
#   'bidQty': '4.59310000',
#   'askPrice': '0.06581400',
#   'askQty': '11.50030000',
#   'openPrice': '0.06640200',
#   'highPrice': '0.06691400',
#   'lowPrice': '0.06513000',
#   'volume': '80093.40450000',
#   'quoteVolume': '5282.83714120',
#   'openTime': 1646329721145,
#   'closeTime': 1646416121145,
#   'firstId': 328230451,
#   'lastId': 328401081,
#   'count': 170631},
#  {'symbol': 'LTCBTC',
#   'priceChange': '-0.00000900',
#   'priceChangePercent': '-0.349',
#   'weightedAvgPrice': '0.00259771',
#   'prevClosePrice': '0.00258400',
#   'lastPrice': '0.00257300',
#   'lastQty': '0.26800000',
#   'bidPrice': '0.00257200',
#   'bidQty': '15.14100000',
#   'askPrice': '0.00257300',
#   'askQty': '88.91200000',
#   'openPrice': '0.00258200',
#   'highPrice': '0.00266500',
#   'lowPrice': '0.00256500',
#   'volume': '83620.21700000',
#   'quoteVolume': '217.22117330',
#   'openTime': 1646329721263,
#   'closeTime': 1646416121263,
#   'firstId': 77495592,
#   'lastId': 77524811,
#   'count': 29220},
#  {'symbol': 'BNBBTC',
#   'priceChange': '0.00008700',
#   'priceChangePercent': '0.919',
#   'weightedAvgPrice': '0.00950987',
#   'prevClosePrice': '0.00946200',
#   'lastPrice': '0.00954900',
#   'lastQty': '1.13000000',
#   'bidPrice': '0.00954800',
#   'bidQty': '27.07400000',
#   'askPrice': '0.00954900',
#   'askQty': '39.11500000',
#   'openPrice': '0.00946200',
#   'highPrice': '0.00958000',
#   'lowPrice': '0.00941700',
#   'volume': '83349.30500000',
#   'quoteVolume': '792.64124360',
#   'openTime': 1646329717679,
#   'closeTime': 1646416117679,
#   'firstId': 180585785,
#   'lastId': 180638434,
#   'count': 52650},
#  {'symbol': 'NEOBTC',
#   'priceChange': '0.00000100',
#   'priceChangePercent': '0.182',
#   'weightedAvgPrice': '0.00055012',
#   'prevClosePrice': '0.00054900',
#   'lastPrice': '0.00054900',
#   'lastQty': '0.25000000',
#   'bidPrice': '0.00054900',
#   'bidQty': '481.68000000',
#   'askPrice': '0.00055000',
#   'askQty': '443.70000000',
#   'openPrice': '0.00054800',
#   'highPrice': '0.00056400',
#   'lowPrice': '0.00054100',
#   'volume': '34212.80000000',
#   'quoteVolume': '18.82127569',
#   'openTime': 1646329721308,
#   'closeTime': 1646416121308,
#   'firstId': 43011545,
#   'lastId': 43016606,
#   'count': 5062},
#  {'symbol': 'QTUMETH',
#   'priceChange': '0.00008400',
#   'priceChangePercent': '3.774',
#   'weightedAvgPrice': '0.00227103',
#   'prevClosePrice': '0.00222600',
#   'lastPrice': '0.00231000',
#   'lastQty': '4.30000000',
#   'bidPrice': '0.00230400',
#   'bidQty': '4.40000000',
#   'askPrice': '0.00230900',
#   'askQty': '519.50000000',
#   'openPrice': '0.00222600',
#   'highPrice': '0.00232000',
#   'lowPrice': '0.00221700',
#   'volume': '9625.60000000',
#   'quoteVolume': '21.85998360',
#   'openTime': 1646329717877,
#   'closeTime': 1646416117877,
#   'firstId': 5203960,
#   'lastId': 5204641,
#   'count': 682},
#  {'symbol': 'EOSETH',
#   'priceChange': '0.00000800',
#   'priceChangePercent': '1.050',
#   'weightedAvgPrice': '0.00076711',
#   'prevClosePrice': '0.00076100',
#   'lastPrice': '0.00077000',
#   'lastQty': '12.10000000',
#   'bidPrice': '0.00076900',
#   'bidQty': '1054.10000000',
#   'askPrice': '0.00077000',
#   'askQty': '1013.90000000',
#   'openPrice': '0.00076200',
#   'highPrice': '0.00077600',
#   'lowPrice': '0.00075900',
#   'volume': '194339.40000000',
#   'quoteVolume': '149.07931190',
#   'openTime': 1646329721406,
#   'closeTime': 1646416121406,
#   'firstId': 22967466,
#   'lastId': 22968436,
#   'count': 971},
#  {'symbol': 'SNTETH',
#   'priceChange': '0.00000096',
#   'priceChangePercent': '4.895',
#   'weightedAvgPrice': '0.00002003',
#   'prevClosePrice': '0.00001960',
#   'lastPrice': '0.00002057',
#   'lastQty': '438.00000000',
#   'bidPrice': '0.00002051',
#   'bidQty': '781.00000000',
#   'askPrice': '0.00002061',
#   'askQty': '4972.00000000',
#   'openPrice': '0.00001961',
#   'highPrice': '0.00002092',
#   'lowPrice': '0.00001952',
#   'volume': '2454998.00000000',
#   'quoteVolume': '49.17010193',
#   'openTime': 1646329630970,
#   'closeTime': 1646416030970,
#   'firstId': 3422473,
#   'lastId': 3423319,
#   'count': 847},
#  {'symbol': 'BNTETH',
#   'priceChange': '0.00001200',
#   'priceChangePercent': '1.430',
#   'weightedAvgPrice': '0.00084940',
#   'prevClosePrice': '0.00084200',
#   'lastPrice': '0.00085100',
#   'lastQty': '283.00000000',
#   'bidPrice': '0.00085000',
#   'bidQty': '70.50000000',
#   'askPrice': '0.00085200',
#   'askQty': '20.40000000',
#   'openPrice': '0.00083900',
#   'highPrice': '0.00085600',
#   'lowPrice': '0.00083800',
#   'volume': '32837.10000000',
#   'quoteVolume': '27.89169600',
#   'openTime': 1646329632347,
#   'closeTime': 1646416032347,
#   'firstId': 2013239,
#   'lastId': 2013800,
#   'count': 562},
#  {'symbol': 'BCCBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.07908100',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'GASBTC',
#   'priceChange': '0.00000340',
#   'priceChangePercent': '3.022',
#   'weightedAvgPrice': '0.00011447',
#   'prevClosePrice': '0.00011280',
#   'lastPrice': '0.00011590',
#   'lastQty': '44.20000000',
#   'bidPrice': '0.00011580',
#   'bidQty': '30.10000000',
#   'askPrice': '0.00011600',
#   'askQty': '33.10000000',
#   'openPrice': '0.00011250',
#   'highPrice': '0.00011900',
#   'lowPrice': '0.00011160',
#   'volume': '68669.10000000',
#   'quoteVolume': '7.86088067',
#   'openTime': 1646329635419,
#   'closeTime': 1646416035419,
#   'firstId': 18045689,
#   'lastId': 18049155,
#   'count': 3467},
#  {'symbol': 'BNBETH',
#   'priceChange': '0.00260000',
#   'priceChangePercent': '1.825',
#   'weightedAvgPrice': '0.14401920',
#   'prevClosePrice': '0.14240000',
#   'lastPrice': '0.14510000',
#   'lastQty': '0.11400000',
#   'bidPrice': '0.14500000',
#   'bidQty': '89.51800000',
#   'askPrice': '0.14510000',
#   'askQty': '25.59700000',
#   'openPrice': '0.14250000',
#   'highPrice': '0.14620000',
#   'lowPrice': '0.14150000',
#   'volume': '25968.59500000',
#   'quoteVolume': '3739.97617460',
#   'openTime': 1646329721793,
#   'closeTime': 1646416121793,
#   'firstId': 45134532,
#   'lastId': 45151517,
#   'count': 16986},
#  {'symbol': 'BTCUSDT',
#   'priceChange': '-1733.35000000',
#   'priceChangePercent': '-4.078',
#   'weightedAvgPrice': '41458.42433451',
#   'prevClosePrice': '42501.05000000',
#   'lastPrice': '40773.53000000',
#   'lastQty': '0.06249000',
#   'bidPrice': '40773.52000000',
#   'bidQty': '2.01769000',
#   'askPrice': '40773.53000000',
#   'askQty': '0.70597000',
#   'openPrice': '42506.88000000',
#   'highPrice': '42703.65000000',
#   'lowPrice': '40414.24000000',
#   'volume': '53860.25740000',
#   'quoteVolume': '2232961406.05498510',
#   'openTime': 1646329721976,
#   'closeTime': 1646416121976,
#   'firstId': 1279105364,
#   'lastId': 1280370174,
#   'count': 1264811},
#  {'symbol': 'ETHUSDT',
#   'priceChange': '-138.84000000',
#   'priceChangePercent': '-4.920',
#   'weightedAvgPrice': '2734.10690716',
#   'prevClosePrice': '2822.23000000',
#   'lastPrice': '2683.39000000',
#   'lastQty': '1.37450000',
#   'bidPrice': '2683.38000000',
#   'bidQty': '3.20610000',
#   'askPrice': '2683.39000000',
#   'askQty': '2.88910000',
#   'openPrice': '2822.23000000',
#   'highPrice': '2849.55000000',
#   'lowPrice': '2646.45000000',
#   'volume': '515319.45430000',
#   'quoteVolume': '1408938479.39509000',
#   'openTime': 1646329721908,
#   'closeTime': 1646416121908,
#   'firstId': 773918754,
#   'lastId': 774783552,
#   'count': 864799},
#  {'symbol': 'HSRBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00041400',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'OAXETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00017780',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DNTETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00002801',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MCOETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00577200',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'ICNETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00166300',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MCOBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00021140',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'WTCBTC',
#   'priceChange': '-0.00000001',
#   'priceChangePercent': '-0.097',
#   'weightedAvgPrice': '0.00001029',
#   'prevClosePrice': '0.00001037',
#   'lastPrice': '0.00001035',
#   'lastQty': '474.00000000',
#   'bidPrice': '0.00001035',
#   'bidQty': '61.00000000',
#   'askPrice': '0.00001037',
#   'askQty': '886.00000000',
#   'openPrice': '0.00001036',
#   'highPrice': '0.00001042',
#   'lowPrice': '0.00001014',
#   'volume': '581713.69000000',
#   'quoteVolume': '5.98411656',
#   'openTime': 1646329706380,
#   'closeTime': 1646416106380,
#   'firstId': 19191499,
#   'lastId': 19192936,
#   'count': 1438},
#  {'symbol': 'WTCETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00023700',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'LRCBTC',
#   'priceChange': '0.00000054',
#   'priceChangePercent': '2.961',
#   'weightedAvgPrice': '0.00001843',
#   'prevClosePrice': '0.00001823',
#   'lastPrice': '0.00001878',
#   'lastQty': '31.00000000',
#   'bidPrice': '0.00001877',
#   'bidQty': '555.00000000',
#   'askPrice': '0.00001878',
#   'askQty': '1290.00000000',
#   'openPrice': '0.00001824',
#   'highPrice': '0.00001885',
#   'lowPrice': '0.00001806',
#   'volume': '1098109.00000000',
#   'quoteVolume': '20.23769137',
#   'openTime': 1646329720874,
#   'closeTime': 1646416120874,
#   'firstId': 18399882,
#   'lastId': 18404960,
#   'count': 5079},
#  {'symbol': 'LRCETH',
#   'priceChange': '0.00001122',
#   'priceChangePercent': '4.081',
#   'weightedAvgPrice': '0.00028007',
#   'prevClosePrice': '0.00027435',
#   'lastPrice': '0.00028614',
#   'lastQty': '6.00000000',
#   'bidPrice': '0.00028499',
#   'bidQty': '177.00000000',
#   'askPrice': '0.00028567',
#   'askQty': '391.00000000',
#   'openPrice': '0.00027492',
#   'highPrice': '0.00028616',
#   'lowPrice': '0.00027321',
#   'volume': '199716.00000000',
#   'quoteVolume': '55.93518398',
#   'openTime': 1646329721877,
#   'closeTime': 1646416121877,
#   'firstId': 4270599,
#   'lastId': 4271436,
#   'count': 838},
#  {'symbol': 'QTUMBTC',
#   'priceChange': '0.00000380',
#   'priceChangePercent': '2.568',
#   'weightedAvgPrice': '0.00015026',
#   'prevClosePrice': '0.00014810',
#   'lastPrice': '0.00015180',
#   'lastQty': '36.30000000',
#   'bidPrice': '0.00015170',
#   'bidQty': '3.50000000',
#   'askPrice': '0.00015190',
#   'askQty': '120.90000000',
#   'openPrice': '0.00014800',
#   'highPrice': '0.00015230',
#   'lowPrice': '0.00014750',
#   'volume': '43859.40000000',
#   'quoteVolume': '6.59016876',
#   'openTime': 1646329717560,
#   'closeTime': 1646416117560,
#   'firstId': 22495750,
#   'lastId': 22501962,
#   'count': 6213},
#  {'symbol': 'YOYOBTC',
#   'priceChange': '0.00000003',
#   'priceChangePercent': '30.000',
#   'weightedAvgPrice': '0.00000012',
#   'prevClosePrice': '0.00000010',
#   'lastPrice': '0.00000013',
#   'lastQty': '762203.00000000',
#   'bidPrice': '0.00000013',
#   'bidQty': '9479120.00000000',
#   'askPrice': '0.00000014',
#   'askQty': '6203080.00000000',
#   'openPrice': '0.00000010',
#   'highPrice': '0.00000014',
#   'lowPrice': '0.00000010',
#   'volume': '183353688.00000000',
#   'quoteVolume': '21.89651701',
#   'openTime': 1646329721481,
#   'closeTime': 1646416121481,
#   'firstId': 7150158,
#   'lastId': 7154699,
#   'count': 4542},
#  {'symbol': 'OMGBTC',
#   'priceChange': '0.00000120',
#   'priceChangePercent': '1.208',
#   'weightedAvgPrice': '0.00010017',
#   'prevClosePrice': '0.00009950',
#   'lastPrice': '0.00010050',
#   'lastQty': '281.90000000',
#   'bidPrice': '0.00010040',
#   'bidQty': '133.10000000',
#   'askPrice': '0.00010060',
#   'askQty': '712.50000000',
#   'openPrice': '0.00009930',
#   'highPrice': '0.00010230',
#   'lowPrice': '0.00009890',
#   'volume': '270013.90000000',
#   'quoteVolume': '27.04735787',
#   'openTime': 1646329717688,
#   'closeTime': 1646416117688,
#   'firstId': 24820829,
#   'lastId': 24824021,
#   'count': 3193},
#  {'symbol': 'OMGETH',
#   'priceChange': '0.00003300',
#   'priceChangePercent': '2.209',
#   'weightedAvgPrice': '0.00151707',
#   'prevClosePrice': '0.00149400',
#   'lastPrice': '0.00152700',
#   'lastQty': '70.30000000',
#   'bidPrice': '0.00152600',
#   'bidQty': '158.80000000',
#   'askPrice': '0.00152800',
#   'askQty': '366.20000000',
#   'openPrice': '0.00149400',
#   'highPrice': '0.00155300',
#   'lowPrice': '0.00149300',
#   'volume': '32465.30000000',
#   'quoteVolume': '49.25227410',
#   'openTime': 1646329720536,
#   'closeTime': 1646416120536,
#   'firstId': 5630528,
#   'lastId': 5631470,
#   'count': 943},
#  {'symbol': 'ZRXBTC',
#   'priceChange': '-0.00000011',
#   'priceChangePercent': '-0.875',
#   'weightedAvgPrice': '0.00001250',
#   'prevClosePrice': '0.00001256',
#   'lastPrice': '0.00001246',
#   'lastQty': '171.00000000',
#   'bidPrice': '0.00001244',
#   'bidQty': '114.00000000',
#   'askPrice': '0.00001246',
#   'askQty': '1815.00000000',
#   'openPrice': '0.00001257',
#   'highPrice': '0.00001279',
#   'lowPrice': '0.00001237',
#   'volume': '742426.00000000',
#   'quoteVolume': '9.28326825',
#   'openTime': 1646329720391,
#   'closeTime': 1646416120391,
#   'firstId': 24096306,
#   'lastId': 24098303,
#   'count': 1998},
#  {'symbol': 'ZRXETH',
#   'priceChange': '0.00000040',
#   'priceChangePercent': '0.212',
#   'weightedAvgPrice': '0.00018915',
#   'prevClosePrice': '0.00018950',
#   'lastPrice': '0.00018920',
#   'lastQty': '27.00000000',
#   'bidPrice': '0.00018890',
#   'bidQty': '1763.00000000',
#   'askPrice': '0.00018920',
#   'askQty': '2158.00000000',
#   'openPrice': '0.00018880',
#   'highPrice': '0.00019460',
#   'lowPrice': '0.00018740',
#   'volume': '186972.00000000',
#   'quoteVolume': '35.36586640',
#   'openTime': 1646329711516,
#   'closeTime': 1646416111516,
#   'firstId': 5236700,
#   'lastId': 5237073,
#   'count': 374},
#  {'symbol': 'STRATBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00003085',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'STRATETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00105300',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SNGLSBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000013',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SNGLSETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00005306',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BQXBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00008703',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BQXETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00126350',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'KNCBTC',
#   'priceChange': '0.00000011',
#   'priceChangePercent': '0.168',
#   'weightedAvgPrice': '0.00006678',
#   'prevClosePrice': '0.00006565',
#   'lastPrice': '0.00006568',
#   'lastQty': '114.10000000',
#   'bidPrice': '0.00006560',
#   'bidQty': '11.70000000',
#   'askPrice': '0.00006569',
#   'askQty': '373.50000000',
#   'openPrice': '0.00006557',
#   'highPrice': '0.00006986',
#   'lowPrice': '0.00006310',
#   'volume': '1122887.30000000',
#   'quoteVolume': '74.98336761',
#   'openTime': 1646329717907,
#   'closeTime': 1646416117907,
#   'firstId': 17711526,
#   'lastId': 17719199,
#   'count': 7674},
#  {'symbol': 'KNCETH',
#   'priceChange': '0.00001120',
#   'priceChangePercent': '1.135',
#   'weightedAvgPrice': '0.00102645',
#   'prevClosePrice': '0.00098880',
#   'lastPrice': '0.00099830',
#   'lastQty': '12.90000000',
#   'bidPrice': '0.00099610',
#   'bidQty': '12.80000000',
#   'askPrice': '0.00099810',
#   'askQty': '186.70000000',
#   'openPrice': '0.00098710',
#   'highPrice': '0.00106130',
#   'lowPrice': '0.00095790',
#   'volume': '854734.30000000',
#   'quoteVolume': '877.34237681',
#   'openTime': 1646329715820,
#   'closeTime': 1646416115820,
#   'firstId': 4426392,
#   'lastId': 4430818,
#   'count': 4427},
#  {'symbol': 'FUNBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000029',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'FUNETH',
#   'priceChange': '0.00000035',
#   'priceChangePercent': '9.831',
#   'weightedAvgPrice': '0.00000371',
#   'prevClosePrice': '0.00000357',
#   'lastPrice': '0.00000391',
#   'lastQty': '18199.00000000',
#   'bidPrice': '0.00000390',
#   'bidQty': '125974.00000000',
#   'askPrice': '0.00000392',
#   'askQty': '63865.00000000',
#   'openPrice': '0.00000356',
#   'highPrice': '0.00000395',
#   'lowPrice': '0.00000354',
#   'volume': '12995915.00000000',
#   'quoteVolume': '48.26988895',
#   'openTime': 1646329695250,
#   'closeTime': 1646416095250,
#   'firstId': 2999986,
#   'lastId': 3000925,
#   'count': 940},
#  {'symbol': 'SNMBTC',
#   'priceChange': '0.00000001',
#   'priceChangePercent': '0.312',
#   'weightedAvgPrice': '0.00000328',
#   'prevClosePrice': '0.00000320',
#   'lastPrice': '0.00000321',
#   'lastQty': '859.00000000',
#   'bidPrice': '0.00000321',
#   'bidQty': '4352.00000000',
#   'askPrice': '0.00000322',
#   'askQty': '201.00000000',
#   'openPrice': '0.00000320',
#   'highPrice': '0.00000334',
#   'lowPrice': '0.00000314',
#   'volume': '1527041.00000000',
#   'quoteVolume': '5.00418760',
#   'openTime': 1646328857141,
#   'closeTime': 1646415257141,
#   'firstId': 9167185,
#   'lastId': 9168653,
#   'count': 1469},
#  {'symbol': 'SNMETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004986',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'NEOETH',
#   'priceChange': '0.00009000',
#   'priceChangePercent': '1.090',
#   'weightedAvgPrice': '0.00830954',
#   'prevClosePrice': '0.00825000',
#   'lastPrice': '0.00835000',
#   'lastQty': '5.62000000',
#   'bidPrice': '0.00835000',
#   'bidQty': '39.30000000',
#   'askPrice': '0.00836000',
#   'askQty': '440.38000000',
#   'openPrice': '0.00826000',
#   'highPrice': '0.00844000',
#   'lowPrice': '0.00821000',
#   'volume': '22431.07000000',
#   'quoteVolume': '186.39179910',
#   'openTime': 1646329721489,
#   'closeTime': 1646416121489,
#   'firstId': 10659395,
#   'lastId': 10660901,
#   'count': 1507},
#  {'symbol': 'IOTABTC',
#   'priceChange': '0.00000034',
#   'priceChangePercent': '1.902',
#   'weightedAvgPrice': '0.00001804',
#   'prevClosePrice': '0.00001787',
#   'lastPrice': '0.00001822',
#   'lastQty': '30.00000000',
#   'bidPrice': '0.00001821',
#   'bidQty': '2616.00000000',
#   'askPrice': '0.00001823',
#   'askQty': '606.00000000',
#   'openPrice': '0.00001788',
#   'highPrice': '0.00001829',
#   'lowPrice': '0.00001771',
#   'volume': '535601.00000000',
#   'quoteVolume': '9.65990182',
#   'openTime': 1646329720968,
#   'closeTime': 1646416120968,
#   'firstId': 32613507,
#   'lastId': 32618669,
#   'count': 5163},
#  {'symbol': 'IOTAETH',
#   'priceChange': '0.00000760',
#   'priceChangePercent': '2.824',
#   'weightedAvgPrice': '0.00027144',
#   'prevClosePrice': '0.00026810',
#   'lastPrice': '0.00027670',
#   'lastQty': '56.00000000',
#   'bidPrice': '0.00027650',
#   'bidQty': '37.00000000',
#   'askPrice': '0.00027750',
#   'askQty': '56.00000000',
#   'openPrice': '0.00026910',
#   'highPrice': '0.00027820',
#   'lowPrice': '0.00026710',
#   'volume': '120513.00000000',
#   'quoteVolume': '32.71217950',
#   'openTime': 1646329721501,
#   'closeTime': 1646416121501,
#   'firstId': 7620635,
#   'lastId': 7621013,
#   'count': 379},
#  {'symbol': 'LINKBTC',
#   'priceChange': '0.00000030',
#   'priceChangePercent': '0.087',
#   'weightedAvgPrice': '0.00034755',
#   'prevClosePrice': '0.00034610',
#   'lastPrice': '0.00034640',
#   'lastQty': '66.47000000',
#   'bidPrice': '0.00034620',
#   'bidQty': '338.77000000',
#   'askPrice': '0.00034640',
#   'askQty': '238.92000000',
#   'openPrice': '0.00034610',
#   'highPrice': '0.00035300',
#   'lowPrice': '0.00034360',
#   'volume': '356977.48000000',
#   'quoteVolume': '124.06577496',
#   'openTime': 1646329721973,
#   'closeTime': 1646416121973,
#   'firstId': 75706751,
#   'lastId': 75720824,
#   'count': 14074},
#  {'symbol': 'LINKETH',
#   'priceChange': '0.00005000',
#   'priceChangePercent': '0.959',
#   'weightedAvgPrice': '0.00526499',
#   'prevClosePrice': '0.00521300',
#   'lastPrice': '0.00526300',
#   'lastQty': '2.91000000',
#   'bidPrice': '0.00526100',
#   'bidQty': '84.95000000',
#   'askPrice': '0.00526500',
#   'askQty': '39.65000000',
#   'openPrice': '0.00521300',
#   'highPrice': '0.00532400',
#   'lowPrice': '0.00518900',
#   'volume': '104868.01000000',
#   'quoteVolume': '552.12901785',
#   'openTime': 1646329720516,
#   'closeTime': 1646416120516,
#   'firstId': 15975149,
#   'lastId': 15978462,
#   'count': 3314},
#  {'symbol': 'XVGBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000024',
#   'prevClosePrice': '0.00000024',
#   'lastPrice': '0.00000024',
#   'lastQty': '1030.00000000',
#   'bidPrice': '0.00000023',
#   'bidQty': '32243804.00000000',
#   'askPrice': '0.00000024',
#   'askQty': '6233636.00000000',
#   'openPrice': '0.00000024',
#   'highPrice': '0.00000024',
#   'lowPrice': '0.00000023',
#   'volume': '13694434.00000000',
#   'quoteVolume': '3.23933755',
#   'openTime': 1646329718067,
#   'closeTime': 1646416118067,
#   'firstId': 28954851,
#   'lastId': 28955254,
#   'count': 404},
#  {'symbol': 'XVGETH',
#   'priceChange': '0.00000002',
#   'priceChangePercent': '0.556',
#   'weightedAvgPrice': '0.00000356',
#   'prevClosePrice': '0.00000360',
#   'lastPrice': '0.00000362',
#   'lastQty': '74470.00000000',
#   'bidPrice': '0.00000361',
#   'bidQty': '20533.00000000',
#   'askPrice': '0.00000363',
#   'askQty': '86739.00000000',
#   'openPrice': '0.00000360',
#   'highPrice': '0.00000364',
#   'lowPrice': '0.00000351',
#   'volume': '17758498.00000000',
#   'quoteVolume': '63.29618919',
#   'openTime': 1646329719860,
#   'closeTime': 1646416119860,
#   'firstId': 10602345,
#   'lastId': 10603185,
#   'count': 841},
#  {'symbol': 'SALTBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004250',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SALTETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00113800',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MDABTC',
#   'priceChange': '0.00000019',
#   'priceChangePercent': '1.919',
#   'weightedAvgPrice': '0.00000998',
#   'prevClosePrice': '0.00000988',
#   'lastPrice': '0.00001009',
#   'lastQty': '874.00000000',
#   'bidPrice': '0.00001009',
#   'bidQty': '688.00000000',
#   'askPrice': '0.00001010',
#   'askQty': '12.00000000',
#   'openPrice': '0.00000990',
#   'highPrice': '0.00001017',
#   'lowPrice': '0.00000980',
#   'volume': '1025842.00000000',
#   'quoteVolume': '10.23441618',
#   'openTime': 1646329687098,
#   'closeTime': 1646416087098,
#   'firstId': 14769816,
#   'lastId': 14774212,
#   'count': 4397},
#  {'symbol': 'MDAETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00181150',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'MTLBTC',
#   'priceChange': '0.00000033',
#   'priceChangePercent': '0.927',
#   'weightedAvgPrice': '0.00003557',
#   'prevClosePrice': '0.00003559',
#   'lastPrice': '0.00003592',
#   'lastQty': '652.40000000',
#   'bidPrice': '0.00003587',
#   'bidQty': '600.00000000',
#   'askPrice': '0.00003593',
#   'askQty': '25.10000000',
#   'openPrice': '0.00003559',
#   'highPrice': '0.00003606',
#   'lowPrice': '0.00003491',
#   'volume': '867446.30000000',
#   'quoteVolume': '30.85137769',
#   'openTime': 1646329700170,
#   'closeTime': 1646416100170,
#   'firstId': 18799639,
#   'lastId': 18803009,
#   'count': 3371},
#  {'symbol': 'MTLETH',
#   'priceChange': '0.00001120',
#   'priceChangePercent': '2.092',
#   'weightedAvgPrice': '0.00053870',
#   'prevClosePrice': '0.00053450',
#   'lastPrice': '0.00054670',
#   'lastQty': '983.00000000',
#   'bidPrice': '0.00054470',
#   'bidQty': '39.00000000',
#   'askPrice': '0.00054570',
#   'askQty': '1293.90000000',
#   'openPrice': '0.00053550',
#   'highPrice': '0.00054770',
#   'lowPrice': '0.00053090',
#   'volume': '609171.60000000',
#   'quoteVolume': '328.15815434',
#   'openTime': 1646329721859,
#   'closeTime': 1646416121859,
#   'firstId': 2832111,
#   'lastId': 2834126,
#   'count': 2016},
#  {'symbol': 'SUBBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000457',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'SUBETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00012334',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'EOSBTC',
#   'priceChange': '0.00000010',
#   'priceChangePercent': '0.198',
#   'weightedAvgPrice': '0.00005070',
#   'prevClosePrice': '0.00005060',
#   'lastPrice': '0.00005070',
#   'lastQty': '52.60000000',
#   'bidPrice': '0.00005060',
#   'bidQty': '6224.00000000',
#   'askPrice': '0.00005070',
#   'askQty': '2707.40000000',
#   'openPrice': '0.00005060',
#   'highPrice': '0.00005140',
#   'lowPrice': '0.00005000',
#   'volume': '385108.90000000',
#   'quoteVolume': '19.52632406',
#   'openTime': 1646329721396,
#   'closeTime': 1646416121396,
#   'firstId': 71275314,
#   'lastId': 71277906,
#   'count': 2593},
#  {'symbol': 'SNTBTC',
#   'priceChange': '0.00000006',
#   'priceChangePercent': '4.615',
#   'weightedAvgPrice': '0.00000133',
#   'prevClosePrice': '0.00000131',
#   'lastPrice': '0.00000136',
#   'lastQty': '795.00000000',
#   'bidPrice': '0.00000135',
#   'bidQty': '83254.00000000',
#   'askPrice': '0.00000136',
#   'askQty': '109355.00000000',
#   'openPrice': '0.00000130',
#   'highPrice': '0.00000138',
#   'lowPrice': '0.00000128',
#   'volume': '6884755.00000000',
#   'quoteVolume': '9.14057285',
#   'openTime': 1646329704523,
#   'closeTime': 1646416104523,
#   'firstId': 10876398,
#   'lastId': 10879630,
#   'count': 3233},
#  {'symbol': 'ETCETH',
#   'priceChange': '0.00006000',
#   'priceChangePercent': '0.569',
#   'weightedAvgPrice': '0.01070735',
#   'prevClosePrice': '0.01051000',
#   'lastPrice': '0.01060000',
#   'lastQty': '2.59000000',
#   'bidPrice': '0.01060000',
#   'bidQty': '211.97000000',
#   'askPrice': '0.01062000',
#   'askQty': '70.23000000',
#   'openPrice': '0.01054000',
#   'highPrice': '0.01099000',
#   'lowPrice': '0.01044000',
#   'volume': '12924.63000000',
#   'quoteVolume': '138.38850690',
#   'openTime': 1646329701354,
#   'closeTime': 1646416101354,
#   'firstId': 7526493,
#   'lastId': 7528006,
#   'count': 1514},
#  {'symbol': 'ETCBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00070433',
#   'prevClosePrice': '0.00069900',
#   'lastPrice': '0.00069900',
#   'lastQty': '20.67000000',
#   'bidPrice': '0.00069800',
#   'bidQty': '1060.00000000',
#   'askPrice': '0.00069900',
#   'askQty': '160.31000000',
#   'openPrice': '0.00069900',
#   'highPrice': '0.00073100',
#   'lowPrice': '0.00069400',
#   'volume': '54900.72000000',
#   'quoteVolume': '38.66795252',
#   'openTime': 1646329721248,
#   'closeTime': 1646416121248,
#   'firstId': 38229059,
#   'lastId': 38234853,
#   'count': 5795},
#  {'symbol': 'MTHBTC',
#   'priceChange': '0.00000002',
#   'priceChangePercent': '5.405',
#   'weightedAvgPrice': '0.00000037',
#   'prevClosePrice': '0.00000037',
#   'lastPrice': '0.00000039',
#   'lastQty': '571042.00000000',
#   'bidPrice': '0.00000039',
#   'bidQty': '110491.00000000',
#   'askPrice': '0.00000040',
#   'askQty': '365229.00000000',
#   'openPrice': '0.00000037',
#   'highPrice': '0.00000042',
#   'lowPrice': '0.00000035',
#   'volume': '16158672.00000000',
#   'quoteVolume': '6.04398776',
#   'openTime': 1646329644948,
#   'closeTime': 1646416044948,
#   'firstId': 7358762,
#   'lastId': 7360011,
#   'count': 1250},
#  {'symbol': 'MTHETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004135',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'ENGBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00006200',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'ENGETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00186480',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DNTBTC',
#   'priceChange': '0.00000002',
#   'priceChangePercent': '1.176',
#   'weightedAvgPrice': '0.00000184',
#   'prevClosePrice': '0.00000169',
#   'lastPrice': '0.00000172',
#   'lastQty': '1559.00000000',
#   'bidPrice': '0.00000171',
#   'bidQty': '83887.00000000',
#   'askPrice': '0.00000172',
#   'askQty': '47680.00000000',
#   'openPrice': '0.00000170',
#   'highPrice': '0.00000197',
#   'lowPrice': '0.00000168',
#   'volume': '13862837.00000000',
#   'quoteVolume': '25.54363451',
#   'openTime': 1646329692016,
#   'closeTime': 1646416092016,
#   'firstId': 13314437,
#   'lastId': 13318461,
#   'count': 4025},
#  {'symbol': 'ZECBTC',
#   'priceChange': '0.00003800',
#   'priceChangePercent': '1.298',
#   'weightedAvgPrice': '0.00301790',
#   'prevClosePrice': '0.00292800',
#   'lastPrice': '0.00296600',
#   'lastQty': '0.49500000',
#   'bidPrice': '0.00296600',
#   'bidQty': '12.00500000',
#   'askPrice': '0.00296800',
#   'askQty': '4.73600000',
#   'openPrice': '0.00292800',
#   'highPrice': '0.00312200',
#   'lowPrice': '0.00289700',
#   'volume': '23305.67900000',
#   'quoteVolume': '70.33429866',
#   'openTime': 1646329714226,
#   'closeTime': 1646416114226,
#   'firstId': 23737805,
#   'lastId': 23749403,
#   'count': 11599},
#  {'symbol': 'ZECETH',
#   'priceChange': '0.00124000',
#   'priceChangePercent': '2.827',
#   'weightedAvgPrice': '0.04566515',
#   'prevClosePrice': '0.04408000',
#   'lastPrice': '0.04510000',
#   'lastQty': '0.37000000',
#   'bidPrice': '0.04504000',
#   'bidQty': '0.71100000',
#   'askPrice': '0.04511000',
#   'askQty': '0.38800000',
#   'openPrice': '0.04386000',
#   'highPrice': '0.04735000',
#   'lowPrice': '0.04358000',
#   'volume': '2571.24200000',
#   'quoteVolume': '117.41616343',
#   'openTime': 1646329721263,
#   'closeTime': 1646416121263,
#   'firstId': 3359343,
#   'lastId': 3360781,
#   'count': 1439},
#  {'symbol': 'BNTBTC',
#   'priceChange': '0.00000015',
#   'priceChangePercent': '0.268',
#   'weightedAvgPrice': '0.00005606',
#   'prevClosePrice': '0.00005596',
#   'lastPrice': '0.00005605',
#   'lastQty': '13.60000000',
#   'bidPrice': '0.00005594',
#   'bidQty': '21.10000000',
#   'askPrice': '0.00005605',
#   'askQty': '98.10000000',
#   'openPrice': '0.00005590',
#   'highPrice': '0.00005639',
#   'lowPrice': '0.00005542',
#   'volume': '52677.80000000',
#   'quoteVolume': '2.95331766',
#   'openTime': 1646329717481,
#   'closeTime': 1646416117481,
#   'firstId': 7308241,
#   'lastId': 7309676,
#   'count': 1436},
#  {'symbol': 'ASTBTC',
#   'priceChange': '0.00000009',
#   'priceChangePercent': '2.601',
#   'weightedAvgPrice': '0.00000354',
#   'prevClosePrice': '0.00000346',
#   'lastPrice': '0.00000355',
#   'lastQty': '2652.00000000',
#   'bidPrice': '0.00000353',
#   'bidQty': '7023.00000000',
#   'askPrice': '0.00000355',
#   'askQty': '431.00000000',
#   'openPrice': '0.00000346',
#   'highPrice': '0.00000370',
#   'lowPrice': '0.00000343',
#   'volume': '1171439.00000000',
#   'quoteVolume': '4.14188122',
#   'openTime': 1646329684045,
#   'closeTime': 1646416084045,
#   'firstId': 14173996,
#   'lastId': 14175535,
#   'count': 1540},
#  {'symbol': 'ASTETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00006960',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DASHBTC',
#   'priceChange': '-0.00000200',
#   'priceChangePercent': '-0.087',
#   'weightedAvgPrice': '0.00228150',
#   'prevClosePrice': '0.00229100',
#   'lastPrice': '0.00228800',
#   'lastQty': '2.84200000',
#   'bidPrice': '0.00228500',
#   'bidQty': '20.00000000',
#   'askPrice': '0.00228800',
#   'askQty': '22.35000000',
#   'openPrice': '0.00229000',
#   'highPrice': '0.00230700',
#   'lowPrice': '0.00225000',
#   'volume': '6435.17600000',
#   'quoteVolume': '14.68183442',
#   'openTime': 1646329721585,
#   'closeTime': 1646416121585,
#   'firstId': 25232843,
#   'lastId': 25236480,
#   'count': 3638},
#  {'symbol': 'DASHETH',
#   'priceChange': '0.00023000',
#   'priceChangePercent': '0.666',
#   'weightedAvgPrice': '0.03440494',
#   'prevClosePrice': '0.03451000',
#   'lastPrice': '0.03474000',
#   'lastQty': '1.72700000',
#   'bidPrice': '0.03473000',
#   'bidQty': '0.15700000',
#   'askPrice': '0.03476000',
#   'askQty': '21.86800000',
#   'openPrice': '0.03451000',
#   'highPrice': '0.03508000',
#   'lowPrice': '0.03378000',
#   'volume': '1525.01400000',
#   'quoteVolume': '52.46801590',
#   'openTime': 1646329717424,
#   'closeTime': 1646416117424,
#   'firstId': 3631941,
#   'lastId': 3632763,
#   'count': 823},
#  {'symbol': 'OAXBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000244',
#   'prevClosePrice': '0.00000237',
#   'lastPrice': '0.00000238',
#   'lastQty': '100.00000000',
#   'bidPrice': '0.00000237',
#   'bidQty': '1143.00000000',
#   'askPrice': '0.00000240',
#   'askQty': '3315.00000000',
#   'openPrice': '0.00000238',
#   'highPrice': '0.00000249',
#   'lowPrice': '0.00000235',
#   'volume': '2082930.00000000',
#   'quoteVolume': '5.07472119',
#   'openTime': 1646329711630,
#   'closeTime': 1646416111630,
#   'firstId': 8710027,
#   'lastId': 8711003,
#   'count': 977},
#  {'symbol': 'ICNBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00005742',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BTGBTC',
#   'priceChange': '0.00002700',
#   'priceChangePercent': '3.734',
#   'weightedAvgPrice': '0.00074987',
#   'prevClosePrice': '0.00072500',
#   'lastPrice': '0.00075000',
#   'lastQty': '3.55000000',
#   'bidPrice': '0.00074800',
#   'bidQty': '27.38000000',
#   'askPrice': '0.00075000',
#   'askQty': '0.90000000',
#   'openPrice': '0.00072300',
#   'highPrice': '0.00077700',
#   'lowPrice': '0.00072300',
#   'volume': '5713.85000000',
#   'quoteVolume': '4.28462285',
#   'openTime': 1646329711492,
#   'closeTime': 1646416111492,
#   'firstId': 14827138,
#   'lastId': 14828954,
#   'count': 1817},
#  {'symbol': 'BTGETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.05274500',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'EVXBTC',
#   'priceChange': '-0.00000113',
#   'priceChangePercent': '-29.199',
#   'weightedAvgPrice': '0.00000329',
#   'prevClosePrice': '0.00000387',
#   'lastPrice': '0.00000274',
#   'lastQty': '313.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000387',
#   'highPrice': '0.00000387',
#   'lowPrice': '0.00000272',
#   'volume': '7981550.00000000',
#   'quoteVolume': '26.29736844',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': 10790629,
#   'lastId': 10797831,
#   'count': 7203},
#  {'symbol': 'EVXETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00062490',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'REQBTC',
#   'priceChange': '0.00000003',
#   'priceChangePercent': '0.581',
#   'weightedAvgPrice': '0.00000518',
#   'prevClosePrice': '0.00000514',
#   'lastPrice': '0.00000519',
#   'lastQty': '551.00000000',
#   'bidPrice': '0.00000519',
#   'bidQty': '392.00000000',
#   'askPrice': '0.00000521',
#   'askQty': '13392.00000000',
#   'openPrice': '0.00000516',
#   'highPrice': '0.00000530',
#   'lowPrice': '0.00000509',
#   'volume': '2191817.00000000',
#   'quoteVolume': '11.35481891',
#   'openTime': 1646329712935,
#   'closeTime': 1646416112935,
#   'firstId': 11723451,
#   'lastId': 11726086,
#   'count': 2636},
#  {'symbol': 'REQETH',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00004995',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'VIBBTC',
#   'priceChange': '0.00000001',
#   'priceChangePercent': '1.587',
#   'weightedAvgPrice': '0.00000065',
#   'prevClosePrice': '0.00000063',
#   'lastPrice': '0.00000064',
#   'lastQty': '90180.00000000',
#   'bidPrice': '0.00000063',
#   'bidQty': '948214.00000000',
#   'askPrice': '0.00000064',
#   'askQty': '195798.00000000',
#   'openPrice': '0.00000063',
#   'highPrice': '0.00000066',
#   'lowPrice': '0.00000063',
#   'volume': '3258484.00000000',
#   'quoteVolume': '2.10351368',
#   'openTime': 1646329714053,
#   'closeTime': 1646416114053,
#   'firstId': 8538032,
#   'lastId': 8538514,
#   'count': 483},
#  {'symbol': 'VIBETH',
#   'priceChange': '0.00000013',
#   'priceChangePercent': '1.354',
#   'weightedAvgPrice': '0.00000968',
#   'prevClosePrice': '0.00000960',
#   'lastPrice': '0.00000973',
#   'lastQty': '82493.00000000',
#   'bidPrice': '0.00000972',
#   'bidQty': '7172.00000000',
#   'askPrice': '0.00000976',
#   'askQty': '13575.00000000',
#   'openPrice': '0.00000960',
# ...
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.51700000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'TRBBTC',
#   'priceChange': '0.00000700',
#   'priceChangePercent': '1.515',
#   'weightedAvgPrice': '0.00046428',
#   'prevClosePrice': '0.00046000',
#   'lastPrice': '0.00046900',
#   'lastQty': '20.88000000',
#   'bidPrice': '0.00046800',
#   'bidQty': '111.53000000',
#   'askPrice': '0.00046900',
#   'askQty': '5.71000000',
#   'openPrice': '0.00046200',
#   'highPrice': '0.00046900',
#   'lowPrice': '0.00045700',
#   'volume': '2951.00000000',
#   'quoteVolume': '1.37008848',
#   'openTime': 1646329716282,
#   'closeTime': 1646416116282,
#   'firstId': 4236262,
#   'lastId': 4237163,
#   'count': 902},
#  {'symbol': 'TRBBUSD',
#   'priceChange': '-0.51000000',
#   'priceChangePercent': '-2.598',
#   'weightedAvgPrice': '19.25869292',
#   'prevClosePrice': '19.60000000',
#   'lastPrice': '19.12000000',
#   'lastQty': '3.21000000',
#   'bidPrice': '19.08000000',
#   'bidQty': '10.47000000',
#   'askPrice': '19.14000000',
#   'askQty': '10.47000000',
#   'openPrice': '19.63000000',
#   'highPrice': '20.02000000',
#   'lowPrice': '18.83000000',
#   'volume': '3329.79000000',
#   'quoteVolume': '64127.40310000',
#   'openTime': 1646329692977,
#   'closeTime': 1646416092977,
#   'firstId': 1690077,
#   'lastId': 1690833,
#   'count': 757},
#  {'symbol': 'TRBUSDT',
#   'priceChange': '-0.54000000',
#   'priceChangePercent': '-2.752',
#   'weightedAvgPrice': '19.23894558',
#   'prevClosePrice': '19.61000000',
#   'lastPrice': '19.08000000',
#   'lastQty': '14.02000000',
#   'bidPrice': '19.10000000',
#   'bidQty': '76.46000000',
#   'askPrice': '19.11000000',
#   'askQty': '1.36000000',
#   'openPrice': '19.62000000',
#   'highPrice': '19.96000000',
#   'lowPrice': '18.82000000',
#   'volume': '79631.69000000',
#   'quoteVolume': '1532029.75000000',
#   'openTime': 1646329716280,
#   'closeTime': 1646416116280,
#   'firstId': 17964591,
#   'lastId': 17976137,
#   'count': 11547},
#  {'symbol': 'ETHNGN',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '805670.00000000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'DOTBIDR',
#   'priceChange': '-12929.00',
#   'priceChangePercent': '-4.965',
#   'weightedAvgPrice': '249382.26',
#   'prevClosePrice': '259955.00',
#   'lastPrice': '247500.00',
#   'lastQty': '0.06000000',
#   'bidPrice': '246659.00',
#   'bidQty': '58.32000000',
#   'askPrice': '247278.00',
#   'askQty': '15.95000000',
#   'openPrice': '260429.00',
#   'highPrice': '261865.00',
#   'lowPrice': '244475.00',
#   'volume': '6576.94000000',
#   'quoteVolume': '1640172143.37',
#   'openTime': 1646329721000,
#   'closeTime': 1646416121000,
#   'firstId': 1187490,
#   'lastId': 1188291,
#   'count': 802},
#  {'symbol': 'LINKAUD',
#   'priceChange': '-0.96000000',
#   'priceChangePercent': '-4.774',
#   'weightedAvgPrice': '19.51821163',
#   'prevClosePrice': '20.02000000',
#   'lastPrice': '19.15000000',
#   'lastQty': '19.58000000',
#   'bidPrice': '19.18000000',
#   'bidQty': '35.39000000',
#   'askPrice': '19.21000000',
#   'askQty': '35.39000000',
#   'openPrice': '20.11000000',
#   'highPrice': '20.53000000',
#   'lowPrice': '19.15000000',
#   'volume': '9515.07000000',
#   'quoteVolume': '185717.14990000',
#   'openTime': 1646329693330,
#   'closeTime': 1646416093330,
#   'firstId': 459047,
#   'lastId': 459284,
#   'count': 238},
#  {'symbol': 'SXPAUD',
#   'priceChange': '0.10100000',
#   'priceChangePercent': '5.716',
#   'weightedAvgPrice': '1.83126335',
#   'prevClosePrice': '1.75400000',
#   'lastPrice': '1.86800000',
#   'lastQty': '6.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '1.76700000',
#   'highPrice': '1.92700000',
#   'lowPrice': '1.73100000',
#   'volume': '41982.90000000',
#   'quoteVolume': '76881.74600000',
#   'openTime': 1643252401360,
#   'closeTime': 1643338801360,
#   'firstId': 446252,
#   'lastId': 446608,
#   'count': 357},
#  {'symbol': 'BZRXBNB',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00514000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BZRXBTC',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.00000463',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BZRXBUSD',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.21640000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'BZRXUSDT',
#   'priceChange': '0.00000000',
#   'priceChangePercent': '0.000',
#   'weightedAvgPrice': '0.00000000',
#   'prevClosePrice': '0.21560000',
#   'lastPrice': '0.00000000',
#   'lastQty': '0.00000000',
#   'bidPrice': '0.00000000',
#   'bidQty': '0.00000000',
#   'askPrice': '0.00000000',
#   'askQty': '0.00000000',
#   'openPrice': '0.00000000',
#   'highPrice': '0.00000000',
#   'lowPrice': '0.00000000',
#   'volume': '0.00000000',
#   'quoteVolume': '0.00000000',
#   'openTime': 1640511842631,
#   'closeTime': 1640598242631,
#   'firstId': -1,
#   'lastId': -1,
#   'count': 0},
#  {'symbol': 'WBTCBTC',
#   'priceChange': '0.00030000',
#   'priceChangePercent': '0.030',
#   'weightedAvgPrice': '1.00032235',
#   'prevClosePrice': '1.00040000',
#   'lastPrice': '1.00050000',
#   'lastQty': '1.61469000',
#   'bidPrice': '1.00040000',
#   'bidQty': '2.39378000',
#   'askPrice': '1.00050000',
#   'askQty': '3.85876000',
#   'openPrice': '1.00020000',
#   'highPrice': '1.00080000',
#   'lowPrice': '0.99990000',
#   'volume': '232.08357000',
#   'quoteVolume': '232.15838322',
#   'openTime': 1646328946229,
#   'closeTime': 1646415346229,
#   'firstId': 2695950,
#   'lastId': 2696895,
#   'count': 946},
#  {'symbol': 'WBTCETH',
#   'priceChange': '0.15000000',
#   'priceChangePercent': '0.997',
#   'weightedAvgPrice': '15.14899726',
#   'prevClosePrice': '15.05000000',
#   'lastPrice': '15.19000000',
#   'lastQty': '0.00394000',
#   'bidPrice': '15.18000000',
#   'bidQty': '0.12583000',
#   'askPrice': '15.21000000',
#   'askQty': '0.21432000',
#   'openPrice': '15.04000000',
#   'highPrice': '15.33000000',
#   'lowPrice': '14.94000000',
#   'volume': '23.39878000',
#   'quoteVolume': '354.46805410',
#   'openTime': 1646329721097,
#   'closeTime': 1646416121097,
#   'firstId': 2566213,
#   'lastId': 2568177,
#   'count': 1965},
#  {'symbol': 'SUSHIBNB',
#   'priceChange': '-0.00002000',
#   'priceChangePercent': '-0.245',
#   'weightedAvgPrice': '0.00820284',
#   'prevClosePrice': '0.00818000',
#   'lastPrice': '0.00814000',
#   'lastQty': '308.80000000',
#   'bidPrice': '0.00813000',
#   'bidQty': '520.00000000',
#   'askPrice': '0.00815000',
#   'askQty': '716.10000000',
#   'openPrice': '0.00816000',
#   'highPrice': '0.00833000',
#   'lowPrice': '0.00810000',
#   'volume': '69213.60000000',
#   'quoteVolume': '567.74797000',
#   'openTime': 1646329705285,
#   'closeTime': 1646416105285,
#   'firstId': 2354115,
#   'lastId': 2355201,
#   'count': 1087},
#  {'symbol': 'SUSHIBTC',
#   'priceChange': '0.00000050',
#   'priceChangePercent': '0.647',
#   'weightedAvgPrice': '0.00007796',
#   'prevClosePrice': '0.00007730',
#   'lastPrice': '0.00007780',
#   'lastQty': '507.60000000',
#   'bidPrice': '0.00007770',
#   'bidQty': '11.60000000',
#   'askPrice': '0.00007780',
#   'askQty': '1950.10000000',
#   'openPrice': '0.00007730',
#   'highPrice': '0.00007930',
#   'lowPrice': '0.00007670',
#   'volume': '236143.70000000',
#   'quoteVolume': '18.40960478',
#   'openTime': 1646329719582,
#   'closeTime': 1646416119582,
#   'firstId': 15864385,
#   'lastId': 15868663,
#   'count': 4279},
#  {'symbol': 'SUSHIBUSD',
#   'priceChange': '-0.11500000',
#   'priceChangePercent': '-3.500',
#   'weightedAvgPrice': '3.22410299',
#   'prevClosePrice': '3.28300000',
#   'lastPrice': '3.17100000',
#   'lastQty': '114.00000000',
#   'bidPrice': '3.16700000',
#   'bidQty': '343.00000000',
#   'askPrice': '3.17000000',
#   'askQty': '110.10000000',
#   'openPrice': '3.28600000',
#   'highPrice': '3.33800000',
#   'lowPrice': '3.13500000',
#   'volume': '200321.50000000',
#   'quoteVolume': '645857.14680000',
#   'openTime': 1646329721787,
#   'closeTime': 1646416121787,
#   'firstId': 7812013,
#   'lastId': 7815560,
#   'count': 3548},
#  {'symbol': 'SUSHIUSDT',
#   'priceChange': '-0.11600000',
#   'priceChangePercent': '-3.532',
#   'weightedAvgPrice': '3.22437435',
#   'prevClosePrice': '3.28400000',
#   'lastPrice': '3.16800000',
#   'lastQty': '125.30000000',
#   'bidPrice': '3.16700000',
#   'bidQty': '313.40000000',
#   'askPrice': '3.16800000',
#   'askQty': '161.60000000',
#   'openPrice': '3.28400000',
#   'highPrice': '3.33900000',
#   'lowPrice': '3.13500000',
#   'volume': '4424228.50000000',
#   'quoteVolume': '14265368.87540000',
#   'openTime': 1646329720413,
#   'closeTime': 1646416120413,
#   'firstId': 74658603,
#   'lastId': 74699791,
#   'count': 41189},
#  {'symbol': 'YFIIBNB',
#   'priceChange': '0.16000000',
#   'priceChangePercent': '3.107',
#   'weightedAvgPrice': '5.35236886',
#   'prevClosePrice': '5.15000000',
#   'lastPrice': '5.31000000',
#   'lastQty': '0.26620000',
#   'bidPrice': '5.28000000',
#   'bidQty': '0.09160000',
#   'askPrice': '5.30000000',
#   'askQty': '0.30160000',
#   'openPrice': '5.15000000',
#   'highPrice': '5.56000000',
#   'lowPrice': '5.12000000',
#   'volume': '96.41380000',
#   'quoteVolume': '516.04222100',
#   'openTime': 1646329519516,
#   'closeTime': 1646415919516,
#   'firstId': 458621,
#   'lastId': 458977,
#   'count': 357},
#  {'symbol': 'YFIIBTC',
#   'priceChange': '0.00160000',
#   'priceChangePercent': '3.265',
#   'weightedAvgPrice': '0.04983474',
#   'prevClosePrice': '0.04900000',
#   'lastPrice': '0.05060000',
#   'lastQty': '0.03180000',
#   'bidPrice': '0.05050000',
#   'bidQty': '2.63820000',
#   'askPrice': '0.05060000',
#   'askQty': '0.87590000',
#   'openPrice': '0.04900000',
#   'highPrice': '0.05160000',
#   'lowPrice': '0.04830000',
#   'volume': '51.32260000',
#   'quoteVolume': '2.55764841',
#   'openTime': 1646329720352,
#   'closeTime': 1646416120352,
#   'firstId': 6174745,
#   'lastId': 6175592,
#   'count': 848},
#  {'symbol': 'YFIIBUSD',
#   'priceChange': '-17.00000000',
#   'priceChangePercent': '-0.819',
#   'weightedAvgPrice': '2073.80047815',
#   'prevClosePrice': '2071.00000000',
#   'lastPrice': '2059.00000000',
#   'lastQty': '0.05700000',
#   'bidPrice': '2057.00000000',
#   'bidQty': '0.24550000',
#   'askPrice': '2061.00000000',
#   'askQty': '0.01890000',
#   'openPrice': '2076.00000000',
#   'highPrice': '2149.00000000',
#   'lowPrice': '1993.00000000',
#   'volume': '28.44300000',
#   'quoteVolume': '58985.10700000',
#   'openTime': 1646329718636,
#   'closeTime': 1646416118636,
#   'firstId': 1708876,
#   'lastId': 1709850,
#   'count': 975},
#  {'symbol': 'YFIIUSDT',
#   'priceChange': '-16.00000000',
#   'priceChangePercent': '-0.771',
#   'weightedAvgPrice': '2066.19394013',
#   'prevClosePrice': '2071.00000000',
#   'lastPrice': '2059.00000000',
#   'lastQty': '0.30500000',
#   'bidPrice': '2058.00000000',
#   'bidQty': '0.27290000',
#   'askPrice': '2060.00000000',
#   'askQty': '0.07410000',
#   'openPrice': '2075.00000000',
#   'highPrice': '2149.00000000',
#   'lowPrice': '1991.00000000',
#   'volume': '701.54280000',
#   'quoteVolume': '1449523.48210000',
#   'openTime': 1646329721114,
#   'closeTime': 1646416121114,
#   'firstId': 24600097,
#   'lastId': 24613652,
#   'count': 13556},
#  {'symbol': 'KSMBNB',
#   'priceChange': '-0.00720000',
#   'priceChangePercent': '-2.161',
#   'weightedAvgPrice': '0.32774472',
#   'prevClosePrice': '0.33330000',
#   'lastPrice': '0.32600000',
#   'lastQty': '1.53700000',
#   'bidPrice': '0.32460000',
#   'bidQty': '1.54400000',
#   'askPrice': '0.32680000',
#   'askQty': '8.74900000',
#   'openPrice': '0.33320000',
#   'highPrice': '0.33410000',
#   'lowPrice': '0.32460000',
#   'volume': '532.92300000',
#   'quoteVolume': '174.66269910',
#   'openTime': 1646329717104,
#   'closeTime': 1646416117104,
#   'firstId': 1063418,
#   'lastId': 1063673,
#   'count': 256},
#  {'symbol': 'KSMBTC',
#   'priceChange': '-0.00007300',
#   'priceChangePercent': '-2.300',
#   'weightedAvgPrice': '0.00311809',
#   'prevClosePrice': '0.00317200',
#   'lastPrice': '0.00310100',
#   'lastQty': '3.23000000',
#   'bidPrice': '0.00310100',
#   'bidQty': '0.16200000',
#   'askPrice': '0.00310300',
#   'askQty': '7.53800000',
#   'openPrice': '0.00317400',
#   'highPrice': '0.00317800',
#   'lowPrice': '0.00307400',
#   'volume': '3970.48200000',
#   'quoteVolume': '12.38030833',
#   'openTime': 1646329720364,
#   'closeTime': 1646416120364,
#   'firstId': 8026248,
#   'lastId': 8030637,
#   'count': 4390},
#  {'symbol': 'KSMBUSD',
#   'priceChange': '-8.40000000',
#   'priceChangePercent': '-6.227',
#   'weightedAvgPrice': '130.19623533',
#   'prevClosePrice': '134.40000000',
#   'lastPrice': '126.50000000',
#   'lastQty': '1.78300000',
#   'bidPrice': '126.40000000',
#   'bidQty': '3.41100000',
#   'askPrice': '126.60000000',
#   'askQty': '3.50300000',
#   'openPrice': '134.90000000',
#   'highPrice': '134.90000000',
#   'lowPrice': '126.30000000',
#   'volume': '2781.88800000',
#   'quoteVolume': '362191.34470000',
#   'openTime': 1646329717464,
#   'closeTime': 1646416117464,
#   'firstId': 6446253,
#   'lastId': 6448270,
#   'count': 2018},
#  {'symbol': 'KSMUSDT',
#   'priceChange': '-8.50000000',
#   'priceChangePercent': '-6.301',
#   'weightedAvgPrice': '129.98883573',
#   'prevClosePrice': '134.80000000',
#   'lastPrice': '126.40000000',
#   'lastQty': '1.42700000',
#   'bidPrice': '126.40000000',
#   'bidQty': '11.10100000',
#   'askPrice': '126.50000000',
#   'askQty': '11.61300000',
#   'openPrice': '134.90000000',
#   'highPrice': '135.00000000',
#   'lowPrice': '126.10000000',
#   'volume': '35327.30300000',
#   'quoteVolume': '4592154.98630000',
#   'openTime': 1646329721813,
#   'closeTime': 1646416121813,
#   'firstId': 52355910,
#   'lastId': 52381714,
#   'count': 25805},
#  {'symbol': 'EGLDBNB',
#   'priceChange': '-0.01270000',
#   'priceChangePercent': '-3.475',
#   'weightedAvgPrice': '0.36006087',
#   'prevClosePrice': '0.36430000',
#   'lastPrice': '0.35280000',
#   'lastQty': '4.76000000',
#   'bidPrice': '0.35300000',
#   'bidQty': '3.63000000',
#   'askPrice': '0.35340000',
#   'askQty': '0.36000000',
#   'openPrice': '0.36550000',
#   'highPrice': '0.36830000',
#   'lowPrice': '0.34720000',
#   'volume': '1288.48000000',
#   'quoteVolume': '463.93123600',
#   'openTime': 1646329711520,
#   'closeTime': 1646416111520,
#   'firstId': 2200876,
#   'lastId': 2202054,
#   'count': 1179},
#  ...]

# %%
from tensortrade.binance.strategy import Binance_strategy
strategy = Binance_strategy(crypto=crypto)
strategy.get_moving_pairs()
# Out:
# (      symbol  priceChangePercent      lastPrice        volume  \
#  0   SHIBUSDT              -2.526     0.00002431  7.017100e+12
#  1    TRXUSDT              -1.192     0.05883000  1.303040e+09
#  2    WINUSDT               5.613     0.00028790  9.831574e+10
#  3    HOTUSDT              -1.918     0.00424400  1.918793e+09
#  4    JSTUSDT              -0.822     0.04703000  2.805431e+08
#  ..       ...                 ...            ...           ...
#  79  EGLDUSDT              -6.262   137.56000000  2.384634e+05
#  80  AAVEUSDT              -1.093   126.70000000  1.913994e+05
#  81   BALUSDT              -4.915    11.80000000  9.892395e+04
#  82   KSMUSDT              -6.301   126.40000000  3.532730e+04
#  83  YFIIUSDT              -0.771  2059.00000000  7.015428e+02
#
#      bidAskQtyChangePercent   count
#  0                 4.343506  242906
#  1               787.701763  129566
#  2                 4.293181   94818
#  3               219.932579   35474
#  4              1381.307312   11707
#  ..                     ...     ...
#  79               18.421053   77746
#  80               20.540843   80273
#  81               27.883539    9891
#  82                4.612197   25805
#  83              170.428728   13556
#
#  [84 rows x 6 columns],
#  None,
#  None)

# %%
crypto.pair.info.pair
# Out:
# 'BTCUSDT'

# %%
from tensortrade.binance.futures import Binance_futures
futures = Binance_futures(futures_client=crypto.futures_client)
futures1 = futures.filter_buy_sell_ratio(symbol='BTCUSDT', period='5m')
futures2 = futures.filter_top_long_short_accounts(symbol='DOTUSDT', period='5m')
futures2

# %%
results = futures_client.get_top_long_short_accounts(symbol='DOTUSDT', period='5m')
df = pd.DataFrame([result.__dict__ for result in results])[['timestamp', 'longShortRatio']]
df = df.rename(columns={'timestamp': 'time', 'longShortRatio': 'long_short_ratio'})
df = df.set_index('time').sort_index().reset_index(drop=True)
df

# %%
interest = futures_client.get_top_long_short_accounts(symbol='BTCUSDT', period='5m')
df = pd.DataFrame([interest.__dict__ for interest in interest])
df

# %%
interest = futures_client.get_open_interest_stats(symbol='BTCUSDT', period='5m')
df = pd.DataFrame([interest.__dict__ for interest in interest])
df
