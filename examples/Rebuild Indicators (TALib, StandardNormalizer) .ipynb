# %%
import talib
from talib.abstract import Function
import numpy as np
import pandas as pd

from gym import Space
from copy import copy
from abc import abstractmethod
from typing import Union, List, Callable, Dict

from tensortrade.features import FeatureTransformer
from tensortrade.features.indicators import TAlibIndicator
from loguru import logger

# %%
import pandas as pd

from tensortrade.features.scalers import MinMaxNormalizer, ComparisonNormalizer, PercentChangeNormalizer, StandardNormalizer
from tensortrade.features.stationarity import FractionalDifference

ohlcv_data = pd.read_csv('./data/Coinbase_BTCUSD_1h.csv', skiprows=1)
ohlcv_data = ohlcv_data[['open','high','low','close','volume']]

# %%
taindicator = TAlibIndicator(indicators=["BBAND", "RSI", "EMA", "SMA", "", None])

# %%
df = pd.read_csv('../tests/data/input/coinbase-1h-btc-usd.csv')

# %%
_df = copy(df)

# %%
transformed = taindicator.transform(df).dropna()
# Out:
# 2019-12-14 14:53:28.941 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - BBANDS
# 2019-12-14 14:53:28.944 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - RSI
# 2019-12-14 14:53:28.946 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - EMA
# 2019-12-14 14:53:28.948 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - SMA

# %%
transformed.to_csv('../tests/data/outputs/ta_transformed.csv')

# %%
df
# Out:
#                    Date  Symbol      Open      High       Low     Close  \
# 0      2019-07-04 01:00  BTCUSD  11849.99  11880.00  11790.01  11849.69
# 1      2019-07-04 00:00  BTCUSD  11976.42  12064.26  11812.01  11849.99
# 2      2019-07-03 23:00  BTCUSD  11920.00  12014.60  11812.03  11976.42
# 3      2019-07-03 22:00  BTCUSD  11396.09  11968.03  11387.93  11920.00
# 4      2019-07-03 21:00  BTCUSD  11377.23  11429.04  11311.11  11396.09
# ...                 ...     ...       ...       ...       ...       ...
# 17578  2017-07-01 15:00  BTCUSD   2459.35   2475.00   2450.00   2467.83
# 17579  2017-07-01 14:00  BTCUSD   2454.43   2473.93   2450.83   2459.35
# 17580  2017-07-01 13:00  BTCUSD   2488.43   2488.43   2454.40   2454.43
# 17581  2017-07-01 12:00  BTCUSD   2509.17   2512.87   2484.99   2488.43
# 17582  2017-07-01 11:00  BTCUSD   2505.56   2513.38   2495.12   2509.17
#
#        VolumeFrom     VolumeTo      bb_upper  bb_middle      bb_lower  \
# ...

# %%
standard = StandardNormalizer()
transformed = standard.transform(df)

# %%
transformed.to_csv('../tests/data/outputs/standard_transformed.csv')

# %%
min_max = MinMaxNormalizer()

# %%
min_max_transformed = min_max.transform(df)

# %%
min_max_transformed.to_csv('../tests/data/outputs/min_max_transformed.csv')

# %%
com_normalizer = ComparisonNormalizer(columns=["Open", "High", "Low", "Close"], comparison_column="Close")

com_normalizer.transform(_df).to_csv('../tests/data/outputs/com_norm_transformed.csv')

# %%
_df
# Out:
#                    Date  Symbol      Open      High       Low     Close  \
# 0      2019-07-04 01:00  BTCUSD  11849.99  11880.00  11790.01  11849.69
# 1      2019-07-04 00:00  BTCUSD  11976.42  12064.26  11812.01  11849.99
# 2      2019-07-03 23:00  BTCUSD  11920.00  12014.60  11812.03  11976.42
# 3      2019-07-03 22:00  BTCUSD  11396.09  11968.03  11387.93  11920.00
# 4      2019-07-03 21:00  BTCUSD  11377.23  11429.04  11311.11  11396.09
# ...                 ...     ...       ...       ...       ...       ...
# 17578  2017-07-01 15:00  BTCUSD   2459.35   2475.00   2450.00   2467.83
# 17579  2017-07-01 14:00  BTCUSD   2454.43   2473.93   2450.83   2459.35
# 17580  2017-07-01 13:00  BTCUSD   2488.43   2488.43   2454.40   2454.43
# 17581  2017-07-01 12:00  BTCUSD   2509.17   2512.87   2484.99   2488.43
# 17582  2017-07-01 11:00  BTCUSD   2505.56   2513.38   2495.12   2509.17
#
#        VolumeFrom     VolumeTo
# 0          303.61   3589525.18
# 1         1627.53  19416056.06
# ...

# %%
pct_normalizer = PercentChangeNormalizer()
pct_normalizer.transform(_df).to_csv('../tests/data/outputs/pct_transforms.csv')

# %%
from tensortrade.features import FeaturePipeline
from tensortrade.features.scalers import MinMaxNormalizer

# %%
ta_indicator = TAlibIndicator(indicators=["BBAND", "RSI", "EMA", "SMA"])
min_max = MinMaxNormalizer()
feature_pipeline = FeaturePipeline(
    [
        ta_indicator, 
        min_max
    ]
)

# %%
feature_pipeline.transform(df).dropna().to_csv('../tests/data/outputs/feature_pipeline_output.csv')
# Out:
# 2019-12-14 14:53:32.892 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - BBANDS
# 2019-12-14 14:53:32.893 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - RSI
# 2019-12-14 14:53:32.894 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - EMA
# 2019-12-14 14:53:32.895 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - SMA

# %%
feature_pipeline.transform(df).dropna().to_csv('../tests/data/outputs/feature_pipeline_output.csv')
# Out:
# 2019-12-14 14:53:33.511 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - BBANDS
# 2019-12-14 14:53:33.512 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - RSI
# 2019-12-14 14:53:33.513 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - EMA
# 2019-12-14 14:53:33.514 | DEBUG    | tensortrade.features.indicators.talib_indicator:transform:110 - SMA

# %%
_df
# Out:
#                    Date  Symbol      Open      High       Low     Close  \
# 0      2019-07-04 01:00  BTCUSD  11849.99  11880.00  11790.01  11849.69
# 1      2019-07-04 00:00  BTCUSD  11976.42  12064.26  11812.01  11849.99
# 2      2019-07-03 23:00  BTCUSD  11920.00  12014.60  11812.03  11976.42
# 3      2019-07-03 22:00  BTCUSD  11396.09  11968.03  11387.93  11920.00
# 4      2019-07-03 21:00  BTCUSD  11377.23  11429.04  11311.11  11396.09
# ...                 ...     ...       ...       ...       ...       ...
# 17578  2017-07-01 15:00  BTCUSD   2459.35   2475.00   2450.00   2467.83
# 17579  2017-07-01 14:00  BTCUSD   2454.43   2473.93   2450.83   2459.35
# 17580  2017-07-01 13:00  BTCUSD   2488.43   2488.43   2454.40   2454.43
# 17581  2017-07-01 12:00  BTCUSD   2509.17   2512.87   2484.99   2488.43
# 17582  2017-07-01 11:00  BTCUSD   2505.56   2513.38   2495.12   2509.17
#
#        VolumeFrom     VolumeTo
# 0          303.61   3589525.18
# 1         1627.53  19416056.06
# ...

# %%
from tensortrade.features.stationarity import FractionalDifference

# %%
transformer = FractionalDifference(
    difference_order=0.5, 
    inplace=True
)

# %%
df_tail = _df.tail(200)

# %%
df_tail
# Out:
#                    Date  Symbol     Open     High      Low    Close  \
# 17383  2017-07-09 18:00  BTCUSD  2553.79  2554.79  2539.42  2539.82
# 17384  2017-07-09 17:00  BTCUSD  2555.67  2555.70  2552.44  2553.79
# 17385  2017-07-09 16:00  BTCUSD  2559.32  2561.96  2553.62  2555.67
# 17386  2017-07-09 15:00  BTCUSD  2556.92  2567.43  2556.92  2559.32
# 17387  2017-07-09 14:00  BTCUSD  2552.33  2557.40  2551.06  2556.92
# ...                 ...     ...      ...      ...      ...      ...
# 17578  2017-07-01 15:00  BTCUSD  2459.35  2475.00  2450.00  2467.83
# 17579  2017-07-01 14:00  BTCUSD  2454.43  2473.93  2450.83  2459.35
# 17580  2017-07-01 13:00  BTCUSD  2488.43  2488.43  2454.40  2454.43
# 17581  2017-07-01 12:00  BTCUSD  2509.17  2512.87  2484.99  2488.43
# 17582  2017-07-01 11:00  BTCUSD  2505.56  2513.38  2495.12  2509.17
#
#        VolumeFrom   VolumeTo
# 17383      201.58  513366.77
# 17384      214.86  548780.46
# 17385      270.41  691472.77
# 17386      281.17  720214.90
# ...

# %%
transformer.transform(df_tail).to_csv("../tests/data/outputs/fractional_diff_transformed.csv")

# %%
_df.tail(500)
# Out:
#                    Date  Symbol     Open     High      Low    Close  \
# 17083  2017-07-22 06:00  BTCUSD  2741.47  2757.15  2736.52  2752.15
# 17084  2017-07-22 05:00  BTCUSD  2707.07  2743.50  2707.05  2741.47
# 17085  2017-07-22 04:00  BTCUSD  2714.90  2719.14  2698.01  2707.07
# 17086  2017-07-22 03:00  BTCUSD  2732.60  2734.03  2709.50  2714.90
# 17087  2017-07-22 02:00  BTCUSD  2702.09  2741.08  2690.97  2732.60
# ...                 ...     ...      ...      ...      ...      ...
# 17578  2017-07-01 15:00  BTCUSD  2459.35  2475.00  2450.00  2467.83
# 17579  2017-07-01 14:00  BTCUSD  2454.43  2473.93  2450.83  2459.35
# 17580  2017-07-01 13:00  BTCUSD  2488.43  2488.43  2454.40  2454.43
# 17581  2017-07-01 12:00  BTCUSD  2509.17  2512.87  2484.99  2488.43
# 17582  2017-07-01 11:00  BTCUSD  2505.56  2513.38  2495.12  2509.17
#
#        VolumeFrom    VolumeTo
# 17083      244.09   670639.24
# 17084      426.85  1168156.52
# 17085      250.39   677280.27
# ...
